# %%
from src.controller.HwpController import HwpController
from collections import OrderedDict

import re, uuid
import numpy as np

# %%
controller = HwpController()
path = '/Users/dobby/Desktop/Workspace/3월 계측보고서(신안산선2공구A-1).hwp'

controller.get_table_list(path, '일자별 발파 및 계측 현황')
# Out:
# unmatched field end

# %%
import re, uuid
import numpy as np

from src.service.ParseService import ParseService


class ComplicatedParser:
    def delete_non_target_data(self, table_data):
        """
        한글 표에서 원하지 않은 부분까지 나온 데이터를 정리하여 리스트로 반환합니다.
        target_data_text에 표에 반복적으로 들어가는 텍스트를 입력하여 필요없는 데이터를 삭제합니다.
        """
        target_data_text = ['일시', '발파', '진동', '소음', 'STA', '시간']

        target_data = [
            sublist for sublist in table_data
            if any(
                entry['row'] in ['0', '1'] and any(keyword in entry['text'] for keyword in target_data_text)
                for entry in sublist
            )
        ]
        
        target_data = [[item for item in items if item['text'] != ''] for items in target_data]

        return target_data

    def extract_columns(self, table_list):
        """
        한글 표에서 공통적인 컬럼 부분을 추출합니다.
        컬럼은 대부분 표의 시작 부분에 작성되기 때문에 row 값은 0 혹은 1에 위치하게 됩니다.
        이후 컬럼 값들이 딕셔너리로 저장되어 있기 때문에 중복을 제거 후 리스트로 반환합니다.
        """
        columns = []
        for items in table_list:
            for item in items:
                if item not in [i for i in columns]:
                    if int(item['row']) == 0 or int(item['row']) == 1:
                        columns.append(item)

        return columns
    
    def extract_non_column_data(self, table_list, columns):
        """
        한글 표에서 컬럼 부분을 제거한 나머지 데이터들을 반환합니다.
        """
        return [[item for item in items[len(columns):] if not int(item['colspan']) > 1]for items in table_list]


    def group_by_date(self, dict_list):
        """
        한글 표 데이터를 날짜 별로 분류하여 리스트로 저장하여 반환합니다.
        날짜 별 분류는 하나의 TableCell에 포함된 동일한 row값들 끼리 묶는 것으로 수행합니다.
        """
        group_list = []

        for items in dict_list:
            rows = list(set([int(item['row']) for item in items]))
            for row in rows:
                temp = [item for item in items if int(item['row'])==row]
                group_list.append(temp)
        
        return [items for items in group_list if len(items) > 1] 
    
    def update_merge_data(self, group_list):
        """
        한글 표에 병합 처리된 셀에 대한 데이터 처리를 완료한 뒤 리스트로 반환합니다.
        SimpleParser에서는 병합 셀이 아닌 셀의 최초 값이 공통 값으로 결정되기 때문에 이를 통해 값을 추가합니다.
        """
        cached_merge_data = []
        cached_head_data = []
        
        for idx, items in enumerate(group_list):
            head_data = [data for data in items if int(data['col']) == 0 and int(data['rowspan']) > 1]
            merge_data = [data for data in items if int(data['col']) != 0 and int(data['rowspan']) > 1]
            
            if head_data:
                cached_head_data = head_data
            if merge_data:
                cached_merge_data = merge_data

            new_items = []
            if any(data not in items for data in cached_head_data):
                new_items.extend(cached_head_data)
            if any(data not in items for data in cached_merge_data):
                new_items.extend(cached_merge_data)

            group_list[idx] = new_items + items
        
        return group_list
    
    def serialize_to_dict(self, group_list, columns):
        """
        컬럼 리스트와 파싱이 끝난 그룹 리스트를 이용해서 데이터를 분류한 뒤 리스트로 반환합니다.
        컬럼 리스트에 대응하는 값들을 그룹 리스트에서 찾아서 추가해주는 작업을 수행합니다.
        """
        serialize_list = []
        find_word = ['일시', '시간', 'cm', 'dB', '측정위치']

        columns = [item for item in columns if int(item['colspan']) <= 1 and any(word in item['text'] for word in find_word)]
        for items in group_list:
            data = {column['text']: item['text'] for column, item in zip(columns, items)}
            serialize_list.append(data)

        return serialize_list

# %%
service = ComplicatedParser()

# %%
table_list = service.delete_non_target_data(controller.get_list())

# %%
columns = service.extract_columns(table_list)

# %%
dict_list = service.extract_non_column_data(table_list, columns)

# %%
group_list = service.group_by_date(dict_list)
group_list
# Out:
# [[{'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월1일'},
#   {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '300.0'},
#   {'row': '2',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+771.25~774.25(종점)'},
#   {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'},
#   {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:47'},
#   {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '2', 'text': '1.6-2.0'},
#   {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '95.7'},
#   {'row': '3',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '2',
#    'text': '5k+172.90~171.65(시점)'},
#   {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.209'},
#   {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '72.51'},
#   {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '73.35'},
#   {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '풍전빌딩'}],
#  [{'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.141'},
#   {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '71.42'},
#   {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '74.79'},
#   {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '로얄프라자'}],
#  [{'row': '6', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월2일'},
#   {'row': '6', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '6', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:02'},
#   {'row': '6', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '6', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '280.0'},
#   {'row': '6',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+854.75~857.25(종점)'},
#   {'row': '6', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.082'},
#   {'row': '6', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '63.14'},
#   {'row': '6', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.99'},
#   {'row': '6', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'},
#   {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:51'},
#   {'row': '7',
#    'col': '3',
#    'colspan': '1',
#    'rowspan': '2',
#    'text': '0.875-2.0'},
#   {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '85.0'},
#   {'row': '7',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '2',
#    'text': '5k+127.0(시점기재갱)'},
#   {'row': '7', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.074'},
#   {'row': '7', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '62.82'},
#   {'row': '7', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '66.59'},
#   {'row': '7', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '풍전빌딩'}],
#  [{'row': '8', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.051'},
#   {'row': '8', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '62.35'},
#   {'row': '8', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '67.68'},
#   {'row': '8', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '로얄프라자'}],
#  [{'row': '9', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'},
#   {'row': '9', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:01'},
#   {'row': '9', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '9', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '273.0'},
#   {'row': '9',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+857.25~859.75(종점)'},
#   {'row': '9', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.103'},
#   {'row': '9', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '61.62'},
#   {'row': '9', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '66.73'},
#   {'row': '9', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '11', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월3일'},
#   {'row': '11', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '11', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '11', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '11', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '224.6'},
#   {'row': '11',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+859.75~862.25(종점)'},
#   {'row': '11', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.083'},
#   {'row': '11', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '63.22'},
#   {'row': '11', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '62.45'},
#   {'row': '11', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '13', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월4일'},
#   {'row': '13', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '13', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:25'},
#   {'row': '13', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '13', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '275.0'},
#   {'row': '13',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+862.25~864.75(종점)'},
#   {'row': '13', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '13', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '13', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '13', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '14', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '14', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:01'},
#   {'row': '14',
#    'col': '3',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '0.875-2.0'},
#   {'row': '14', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '82.0'},
#   {'row': '14',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+850.0(종점기재갱)'},
#   {'row': '14', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.063'},
#   {'row': '14', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.19'},
#   {'row': '14', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.42'},
#   {'row': '14', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월5일'},
#   {'row': '16', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '16', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:05'},
#   {'row': '16', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '16', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '290.0'},
#   {'row': '16',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+864.75~867.25(종점)'},
#   {'row': '16', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '16', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '16', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '16', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '17', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '17', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:38'},
#   {'row': '17', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
#   {'row': '17', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '275.0'},
#   {'row': '17',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+867.25~869.75(종점)'},
#   {'row': '17', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.117'},
#   {'row': '17', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '62.2'},
#   {'row': '17', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.32'},
#   {'row': '17', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '19', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월6일'},
#   {'row': '19', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '19', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '19', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '19', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '160.0'},
#   {'row': '19',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+869.75~871.25종점)'},
#   {'row': '19', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.04'},
#   {'row': '19', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '-'},
#   {'row': '19', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.03'},
#   {'row': '19', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '20', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '20', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:05'},
#   {'row': '20', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '20', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '158.0'},
#   {'row': '20',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+871.25~872.75(종점)'},
#   {'row': '20', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.06'},
#   {'row': '20', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '58.3'},
#   {'row': '20', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '55.55'},
#   {'row': '20', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '22', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월7일'},
#   {'row': '22', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '22', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:00'},
#   {'row': '22', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '22', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '119.0'},
#   {'row': '22',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+872.75~874.25(종점)'},
#   {'row': '22', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.081'},
#   {'row': '22', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '58.9'},
#   {'row': '22', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.14'},
#   {'row': '22', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '23', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '23', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:19'},
#   {'row': '23', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '23', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '110.0'},
#   {'row': '23',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+874.25~875.75(종점)'},
#   {'row': '23', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.038'},
#   {'row': '23', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '55.68'},
#   {'row': '23', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '69.16'},
#   {'row': '23', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월8일'},
#   {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:21'},
#   {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '119.0'},
#   {'row': '2',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+875.75~877.25(종점)'},
#   {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.037'},
#   {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '54.24'},
#   {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '54.27'},
#   {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:36'},
#   {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '112.0'},
#   {'row': '3',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+877.25~878.75(종점)'},
#   {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '5', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월9일'},
#   {'row': '5', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '5', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '9:14'},
#   {'row': '5', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '5', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '82.0'},
#   {'row': '5',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+878.75~880.25(종점)'},
#   {'row': '5', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.048'},
#   {'row': '5', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.73'},
#   {'row': '5', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '52.0'},
#   {'row': '5', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '6', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '6', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:53'},
#   {'row': '6', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '6', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '129.0'},
#   {'row': '6',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+880.25~881.75(종점)'},
#   {'row': '6', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.04'},
#   {'row': '6', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.0'},
#   {'row': '6', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.51'},
#   {'row': '6', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '8', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월10일'},
#   {'row': '8', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '8', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '8', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'},
#   {'row': '8', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '126.0'},
#   {'row': '8',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.75~883.25(종점)'},
#   {'row': '8', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.055'},
#   {'row': '8', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '55.25'},
#   {'row': '8', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.77'},
#   {'row': '8', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '10', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월11일'},
#   {'row': '10', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '10', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '14:57'},
#   {'row': '10', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '10', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '224.8'},
#   {'row': '10',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+883.25~884.75(종점)'},
#   {'row': '10', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.085'},
#   {'row': '10', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '60.66'},
#   {'row': '10', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.56'},
#   {'row': '10', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '12', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월13일'},
#   {'row': '12', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '12', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '12', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '12', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '70.0'},
#   {'row': '12',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+869.75~872.75(종점)'},
#   {'row': '12', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.053'},
#   {'row': '12', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.21'},
#   {'row': '12', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '63.15'},
#   {'row': '12', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '13', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '13', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:33'},
#   {'row': '13', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '13', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '88.0'},
#   {'row': '13',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+872.75~875.75(종점)'},
#   {'row': '13', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.152'},
#   {'row': '13', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '66.9'},
#   {'row': '13', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.79'},
#   {'row': '13', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '14', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'},
#   {'row': '14', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:33'},
#   {'row': '14', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '14', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '70.0'},
#   {'row': '14',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+850.0(종점기재갱)'},
#   {'row': '14', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.152'},
#   {'row': '14', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '66.9'},
#   {'row': '14', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.79'},
#   {'row': '14', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월14일'},
#   {'row': '16', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '16', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '16', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '16', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '85.0'},
#   {'row': '16',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+875.75~878.75(종점)'},
#   {'row': '16', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.093'},
#   {'row': '16', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '66.03'},
#   {'row': '16', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '61.87'},
#   {'row': '16', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '17', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '17', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:55'},
#   {'row': '17', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '17', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '85.0'},
#   {'row': '17',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+878.75~881.75(종점)'},
#   {'row': '17', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '17', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '17', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '17', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '18', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'},
#   {'row': '18', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:00'},
#   {'row': '18',
#    'col': '3',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '0.875-2.0'},
#   {'row': '18', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '95.9'},
#   {'row': '18',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+850.0(종점기재갱)'},
#   {'row': '18', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '18', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '18', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '18', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '20', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월15일'},
#   {'row': '20', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '20', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '10:57'},
#   {'row': '20', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '20', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '169.0'},
#   {'row': '20',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '20', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.13'},
#   {'row': '20', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '64.27'},
#   {'row': '20', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.97'},
#   {'row': '20', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '21', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '21', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:16'},
#   {'row': '21', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '21', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '27.5'},
#   {'row': '21',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.75~884.75(종점)'},
#   {'row': '21', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.014'},
#   {'row': '21', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '49.62'},
#   {'row': '21', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '53.62'},
#   {'row': '21', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월16일'},
#   {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:04'},
#   {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '125.0'},
#   {'row': '2',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.034'},
#   {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '50.22'},
#   {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '62.92'},
#   {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:10'},
#   {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '35.0'},
#   {'row': '3',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+884.75~886.25(종점)'},
#   {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '4', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'},
#   {'row': '4', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:34'},
#   {'row': '4', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '4', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '125.0'},
#   {'row': '4',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.089'},
#   {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '60.05'},
#   {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.12'},
#   {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '5', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '4회'},
#   {'row': '5', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:40'},
#   {'row': '5',
#    'col': '3',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '0.875-2.0'},
#   {'row': '5', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '6.0'},
#   {'row': '5',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+850.0(종점기재갱)'},
#   {'row': '5', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '5', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '5', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
#   {'row': '5', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '7', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월18일'},
#   {'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:03'},
#   {'row': '7', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '190.4'},
#   {'row': '7',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '7', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.107'},
#   {'row': '7', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '60.34'},
#   {'row': '7', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.03'},
#   {'row': '7', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '9', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월19일'},
#   {'row': '9', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '9', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '11:02'},
#   {'row': '9', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '9', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '184.2'},
#   {'row': '9',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '9', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.123'},
#   {'row': '9', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '61.02'},
#   {'row': '9', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '61.74'},
#   {'row': '9', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '11', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월20일'},
#   {'row': '11', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '11', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:02'},
#   {'row': '11', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '11', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '148.0'},
#   {'row': '11',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '11', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.068'},
#   {'row': '11', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.93'},
#   {'row': '11', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.98'},
#   {'row': '11', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '12', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '12', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:01'},
#   {'row': '12', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '12', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '147.0'},
#   {'row': '12',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '12', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.043'},
#   {'row': '12', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '54.16'},
#   {'row': '12', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.38'},
#   {'row': '12', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '14', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월21일'},
#   {'row': '14', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '14', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '14', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '14', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '87.0'},
#   {'row': '14',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '14', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.03'},
#   {'row': '14', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '50.05'},
#   {'row': '14', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.36'},
#   {'row': '14', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '15', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '15', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:00'},
#   {'row': '15', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '15', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '168.0'},
#   {'row': '15',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '15', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.072'},
#   {'row': '15', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.24'},
#   {'row': '15', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.46'},
#   {'row': '15', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '17', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월22일'},
#   {'row': '17', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '17', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '8:51'},
#   {'row': '17', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '17', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '155.0'},
#   {'row': '17',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '17', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.048'},
#   {'row': '17', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.89'},
#   {'row': '17', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.11'},
#   {'row': '17', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '18', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '18', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:36'},
#   {'row': '18', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '18', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '160.0'},
#   {'row': '18',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '18', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.055'},
#   {'row': '18', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.74'},
#   {'row': '18', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.59'},
#   {'row': '18', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '20', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월23일'},
#   {'row': '20', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '20', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '10:45'},
#   {'row': '20', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '20', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '204.6'},
#   {'row': '20',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '20', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '22', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월24일'},
#   {'row': '22', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '22', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:02'},
#   {'row': '22', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '22', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '144.6'},
#   {'row': '22',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '22', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.039'},
#   {'row': '22', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.96'},
#   {'row': '22', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.09'},
#   {'row': '22', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월25일'},
#   {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '11:29'},
#   {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '248.9'},
#   {'row': '2',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.07'},
#   {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '61.38'},
#   {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '63.68'},
#   {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '4', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월26일'},
#   {'row': '4', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '4', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '4', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '4', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '145.0'},
#   {'row': '4',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.03'},
#   {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '53.8'},
#   {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.92'},
#   {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '5', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '5', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:11'},
#   {'row': '5', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '5', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '150.0'},
#   {'row': '5',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '5', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.027'},
#   {'row': '5', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.9'},
#   {'row': '5', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.13'},
#   {'row': '5', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '7', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월27일'},
#   {'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '7', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '145.0'},
#   {'row': '7',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '7', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.039'},
#   {'row': '7', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.68'},
#   {'row': '7', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.96'},
#   {'row': '7', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '8', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '8', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:12'},
#   {'row': '8', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '8', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '149.2'},
#   {'row': '8',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '8', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.029'},
#   {'row': '8', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '50.77'},
#   {'row': '8', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.69'},
#   {'row': '8', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '10', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월28일'},
#   {'row': '10', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
#   {'row': '10', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
#   {'row': '10', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '10', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '180.0'},
#   {'row': '10',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '10', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.031'},
#   {'row': '10', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '51.15'},
#   {'row': '10', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.3'},
#   {'row': '10', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
#  [{'row': '11', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'},
#   {'row': '11', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:21'},
#   {'row': '11', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'},
#   {'row': '11', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '180.0'},
#   {'row': '11',
#    'col': '5',
#    'colspan': '1',
#    'rowspan': '1',
#    'text': '7k+881.65(종점집수정횡갱)'},
#   {'row': '11', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.038'},
#   {'row': '11', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '54.83'},
#   {'row': '11', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.16'},
#   {'row': '11', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}]]

# %%
# cached_merge_data = []
# cached_head_data = []

# for idx, items in enumerate(group_list):
#     head_data = [data for data in items if int(data['col']) == 0 and int(data['rowspan']) > 1]
#     merge_data = [data for data in items if int(data['col']) != 0 and int(data['rowspan']) > 1]
    
#     # head_data는 변경되는데 merge_data가 rowspan조건에 부합하지 않아서 이전의 merge_data값을 가지고 있어서 에러가 생김
#     if head_data:
#         if len(merge_data) == 0 and cached_merge_data:
#             cached_merge_data = []
#         cached_head_data = head_data
#     if merge_data:
#         cached_merge_data = merge_data

#     for item in items:
#         print(item)
#     print(f'head: {head_data}')
#     print(f'cHead: {cached_head_data}')

#     print(f'merge: {merge_data}')
#     print(f'cMerge: {cached_merge_data}')
#     print("\n\n")

#     new_items = []
#     if any(data not in items for data in cached_head_data):
#         new_items.extend(cached_head_data)
#     if any(data not in items for data in cached_merge_data):
#         new_items.extend(cached_merge_data)

#     group_list[idx] = new_items + items
#     print('=== RESULT ===')
#     for i in group_list[idx]:
#         print(i)
#     print("\n\n")

# %%
data = [
    [{'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월1일'},
     {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'},
     {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'},
     {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'},
     {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '300.0'},
     {'row': '2', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+771.25~774.25(종점)'},
     {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
     {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
     {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'},
     {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}],
    [{'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'},
     {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:47'},
     {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '2', 'text': '1.6-2.0'},
     {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '95.7'},
     {'row': '3', 'col': '5', 'colspan': '1', 'rowspan': '2', 'text': '5k+172.90~171.65(시점)'},
     {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.209'},
     {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '72.51'},
     {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '73.35'},
     {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '풍전빌딩'}],
    [{'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.141'},
     {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '71.42'},
     {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '74.79'},
     {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '로얄프라자'}]
]

max_len = max(len(item) for item in group_list)

for idx, items in enumerate(group_list):
    temp = []
    r = [i for i in range(max_len) if not any(int(item['col']) == i for item in items)]
    if len(r) > 0 and idx != 0:
        temp = [group_list[idx-1][row] for row in r ]
    
    new_item = temp + items
    group_list[idx] = new_item

    for z in group_list[idx]:
        print(z)
    print("\n\n")
# Out:
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월1일'}
# {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '300.0'}
# {'row': '2', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+771.25~774.25(종점)'}
# {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월1일'}
# {'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'}
# {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:47'}
# {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '2', 'text': '1.6-2.0'}
# {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '95.7'}
# {'row': '3', 'col': '5', 'colspan': '1', 'rowspan': '2', 'text': '5k+172.90~171.65(시점)'}
# {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.209'}
# {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '72.51'}
# {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '73.35'}
# {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '풍전빌딩'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월1일'}
# {'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'}
# {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:47'}
# {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '2', 'text': '1.6-2.0'}
# {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '95.7'}
# {'row': '3', 'col': '5', 'colspan': '1', 'rowspan': '2', 'text': '5k+172.90~171.65(시점)'}
# {'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.141'}
# {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '71.42'}
# {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '74.79'}
# {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '로얄프라자'}
#
#
#
# {'row': '6', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월2일'}
# {'row': '6', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '6', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:02'}
# {'row': '6', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '6', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '280.0'}
# {'row': '6', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+854.75~857.25(종점)'}
# {'row': '6', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.082'}
# {'row': '6', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '63.14'}
# {'row': '6', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.99'}
# {'row': '6', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '6', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월2일'}
# {'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'}
# {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:51'}
# {'row': '7', 'col': '3', 'colspan': '1', 'rowspan': '2', 'text': '0.875-2.0'}
# {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '85.0'}
# {'row': '7', 'col': '5', 'colspan': '1', 'rowspan': '2', 'text': '5k+127.0(시점기재갱)'}
# {'row': '7', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.074'}
# {'row': '7', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '62.82'}
# {'row': '7', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '66.59'}
# {'row': '7', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '풍전빌딩'}
#
#
#
# {'row': '6', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월2일'}
# {'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '2', 'text': '2회'}
# {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '2', 'text': '11:51'}
# {'row': '7', 'col': '3', 'colspan': '1', 'rowspan': '2', 'text': '0.875-2.0'}
# {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '2', 'text': '85.0'}
# {'row': '7', 'col': '5', 'colspan': '1', 'rowspan': '2', 'text': '5k+127.0(시점기재갱)'}
# {'row': '8', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.051'}
# {'row': '8', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '62.35'}
# {'row': '8', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '67.68'}
# {'row': '8', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '로얄프라자'}
#
#
#
# {'row': '6', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월2일'}
# {'row': '9', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'}
# {'row': '9', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:01'}
# {'row': '9', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '9', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '273.0'}
# {'row': '9', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+857.25~859.75(종점)'}
# {'row': '9', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.103'}
# {'row': '9', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '61.62'}
# {'row': '9', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '66.73'}
# {'row': '9', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '11', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월3일'}
# {'row': '11', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '11', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '11', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '11', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '224.6'}
# {'row': '11', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+859.75~862.25(종점)'}
# {'row': '11', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.083'}
# {'row': '11', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '63.22'}
# {'row': '11', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '62.45'}
# {'row': '11', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '13', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월4일'}
# {'row': '13', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '13', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:25'}
# {'row': '13', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '13', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '275.0'}
# {'row': '13', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+862.25~864.75(종점)'}
# {'row': '13', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '13', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '13', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '13', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '13', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월4일'}
# {'row': '14', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '14', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:01'}
# {'row': '14', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.875-2.0'}
# {'row': '14', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '82.0'}
# {'row': '14', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+850.0(종점기재갱)'}
# {'row': '14', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.063'}
# {'row': '14', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.19'}
# {'row': '14', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.42'}
# {'row': '14', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월5일'}
# {'row': '16', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '16', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:05'}
# {'row': '16', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '16', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '290.0'}
# {'row': '16', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+864.75~867.25(종점)'}
# {'row': '16', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '16', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '16', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '16', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월5일'}
# {'row': '17', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '17', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:38'}
# {'row': '17', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '1.6-2.0'}
# {'row': '17', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '275.0'}
# {'row': '17', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+867.25~869.75(종점)'}
# {'row': '17', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.117'}
# {'row': '17', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '62.2'}
# {'row': '17', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.32'}
# {'row': '17', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '19', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월6일'}
# {'row': '19', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '19', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '19', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '19', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '160.0'}
# {'row': '19', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+869.75~871.25종점)'}
# {'row': '19', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.04'}
# {'row': '19', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '-'}
# {'row': '19', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.03'}
# {'row': '19', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '19', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월6일'}
# {'row': '20', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '20', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:05'}
# {'row': '20', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '20', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '158.0'}
# {'row': '20', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+871.25~872.75(종점)'}
# {'row': '20', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.06'}
# {'row': '20', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '58.3'}
# {'row': '20', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '55.55'}
# {'row': '20', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '22', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월7일'}
# {'row': '22', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '22', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:00'}
# {'row': '22', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '22', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '119.0'}
# {'row': '22', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+872.75~874.25(종점)'}
# {'row': '22', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.081'}
# {'row': '22', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '58.9'}
# {'row': '22', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.14'}
# {'row': '22', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '22', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월7일'}
# {'row': '23', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '23', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:19'}
# {'row': '23', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '23', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '110.0'}
# {'row': '23', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+874.25~875.75(종점)'}
# {'row': '23', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.038'}
# {'row': '23', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '55.68'}
# {'row': '23', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '69.16'}
# {'row': '23', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월8일'}
# {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:21'}
# {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '119.0'}
# {'row': '2', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+875.75~877.25(종점)'}
# {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.037'}
# {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '54.24'}
# {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '54.27'}
# {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월8일'}
# {'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:36'}
# {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '112.0'}
# {'row': '3', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+877.25~878.75(종점)'}
# {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '5', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월9일'}
# {'row': '5', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '5', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '9:14'}
# {'row': '5', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '5', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '82.0'}
# {'row': '5', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+878.75~880.25(종점)'}
# {'row': '5', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.048'}
# {'row': '5', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.73'}
# {'row': '5', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '52.0'}
# {'row': '5', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '5', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월9일'}
# {'row': '6', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '6', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:53'}
# {'row': '6', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '6', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '129.0'}
# {'row': '6', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+880.25~881.75(종점)'}
# {'row': '6', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.04'}
# {'row': '6', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.0'}
# {'row': '6', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.51'}
# {'row': '6', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '8', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월10일'}
# {'row': '8', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '8', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '8', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-1.6'}
# {'row': '8', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '126.0'}
# {'row': '8', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.75~883.25(종점)'}
# {'row': '8', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.055'}
# {'row': '8', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '55.25'}
# {'row': '8', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.77'}
# {'row': '8', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '10', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월11일'}
# {'row': '10', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '10', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '14:57'}
# {'row': '10', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '10', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '224.8'}
# {'row': '10', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+883.25~884.75(종점)'}
# {'row': '10', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.085'}
# {'row': '10', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '60.66'}
# {'row': '10', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.56'}
# {'row': '10', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '12', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월13일'}
# {'row': '12', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '12', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '12', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '12', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '70.0'}
# {'row': '12', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+869.75~872.75(종점)'}
# {'row': '12', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.053'}
# {'row': '12', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.21'}
# {'row': '12', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '63.15'}
# {'row': '12', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '12', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월13일'}
# {'row': '13', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '13', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:33'}
# {'row': '13', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '13', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '88.0'}
# {'row': '13', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+872.75~875.75(종점)'}
# {'row': '13', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.152'}
# {'row': '13', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '66.9'}
# {'row': '13', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.79'}
# {'row': '13', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '12', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월13일'}
# {'row': '14', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'}
# {'row': '14', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:33'}
# {'row': '14', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '14', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '70.0'}
# {'row': '14', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+850.0(종점기재갱)'}
# {'row': '14', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.152'}
# {'row': '14', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '66.9'}
# {'row': '14', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.79'}
# {'row': '14', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월14일'}
# {'row': '16', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '16', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '16', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '16', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '85.0'}
# {'row': '16', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+875.75~878.75(종점)'}
# {'row': '16', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.093'}
# {'row': '16', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '66.03'}
# {'row': '16', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '61.87'}
# {'row': '16', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월14일'}
# {'row': '17', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '17', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:55'}
# {'row': '17', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '17', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '85.0'}
# {'row': '17', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+878.75~881.75(종점)'}
# {'row': '17', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '17', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '17', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '17', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '16', 'col': '0', 'colspan': '1', 'rowspan': '4', 'text': '3월14일'}
# {'row': '18', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'}
# {'row': '18', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:00'}
# {'row': '18', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.875-2.0'}
# {'row': '18', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '95.9'}
# {'row': '18', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+850.0(종점기재갱)'}
# {'row': '18', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '18', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '18', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '18', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '20', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월15일'}
# {'row': '20', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '20', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '10:57'}
# {'row': '20', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '20', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '169.0'}
# {'row': '20', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '20', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.13'}
# {'row': '20', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '64.27'}
# {'row': '20', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.97'}
# {'row': '20', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '20', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월15일'}
# {'row': '21', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '21', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '15:16'}
# {'row': '21', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '21', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '27.5'}
# {'row': '21', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.75~884.75(종점)'}
# {'row': '21', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.014'}
# {'row': '21', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '49.62'}
# {'row': '21', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '53.62'}
# {'row': '21', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월16일'}
# {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:04'}
# {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '125.0'}
# {'row': '2', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.034'}
# {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '50.22'}
# {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '62.92'}
# {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월16일'}
# {'row': '3', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '3', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:10'}
# {'row': '3', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '3', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '35.0'}
# {'row': '3', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+884.75~886.25(종점)'}
# {'row': '3', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '3', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '3', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '3', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월16일'}
# {'row': '4', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '3회'}
# {'row': '4', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:34'}
# {'row': '4', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '4', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '125.0'}
# {'row': '4', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.089'}
# {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '60.05'}
# {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '60.12'}
# {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '5', 'text': '3월16일'}
# {'row': '5', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '4회'}
# {'row': '5', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:40'}
# {'row': '5', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.875-2.0'}
# {'row': '5', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '6.0'}
# {'row': '5', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+850.0(종점기재갱)'}
# {'row': '5', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '5', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '5', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': 'N/T'}
# {'row': '5', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '7', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월18일'}
# {'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:03'}
# {'row': '7', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '190.4'}
# {'row': '7', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '7', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.107'}
# {'row': '7', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '60.34'}
# {'row': '7', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.03'}
# {'row': '7', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '9', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월19일'}
# {'row': '9', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '9', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '11:02'}
# {'row': '9', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '9', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '184.2'}
# {'row': '9', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '9', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.123'}
# {'row': '9', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '61.02'}
# {'row': '9', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '61.74'}
# {'row': '9', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '11', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월20일'}
# {'row': '11', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '11', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:02'}
# {'row': '11', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '11', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '148.0'}
# {'row': '11', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '11', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.068'}
# {'row': '11', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.93'}
# {'row': '11', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.98'}
# {'row': '11', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '11', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월20일'}
# {'row': '12', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '12', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:01'}
# {'row': '12', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '12', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '147.0'}
# {'row': '12', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '12', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.043'}
# {'row': '12', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '54.16'}
# {'row': '12', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.38'}
# {'row': '12', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '14', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월21일'}
# {'row': '14', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '14', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '14', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '14', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '87.0'}
# {'row': '14', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '14', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.03'}
# {'row': '14', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '50.05'}
# {'row': '14', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.36'}
# {'row': '14', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '14', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월21일'}
# {'row': '15', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '15', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:00'}
# {'row': '15', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '15', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '168.0'}
# {'row': '15', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '15', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.072'}
# {'row': '15', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '57.24'}
# {'row': '15', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.46'}
# {'row': '15', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '17', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월22일'}
# {'row': '17', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '17', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '8:51'}
# {'row': '17', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '17', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '155.0'}
# {'row': '17', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '17', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.048'}
# {'row': '17', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.89'}
# {'row': '17', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.11'}
# {'row': '17', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '17', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월22일'}
# {'row': '18', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '18', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '18:36'}
# {'row': '18', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '18', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '160.0'}
# {'row': '18', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '18', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.055'}
# {'row': '18', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.74'}
# {'row': '18', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.59'}
# {'row': '18', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '18', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.055'}
# {'row': '18', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.74'}
# {'row': '18', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.59'}
# {'row': '20', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월23일'}
# {'row': '20', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '20', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '10:45'}
# {'row': '20', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '20', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '204.6'}
# {'row': '20', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '20', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '22', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월24일'}
# {'row': '22', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '22', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:02'}
# {'row': '22', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '22', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '144.6'}
# {'row': '22', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '22', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.039'}
# {'row': '22', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '56.96'}
# {'row': '22', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.09'}
# {'row': '22', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '2', 'col': '0', 'colspan': '1', 'rowspan': '2', 'text': '3월25일'}
# {'row': '2', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '2', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '11:29'}
# {'row': '2', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '2', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '248.9'}
# {'row': '2', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '2', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.07'}
# {'row': '2', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '61.38'}
# {'row': '2', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '63.68'}
# {'row': '2', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '4', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월26일'}
# {'row': '4', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '4', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '4', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '4', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '145.0'}
# {'row': '4', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '4', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.03'}
# {'row': '4', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '53.8'}
# {'row': '4', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.92'}
# {'row': '4', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '4', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월26일'}
# {'row': '5', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '5', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:11'}
# {'row': '5', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '5', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '150.0'}
# {'row': '5', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '5', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.027'}
# {'row': '5', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.9'}
# {'row': '5', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '57.13'}
# {'row': '5', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '7', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월27일'}
# {'row': '7', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '7', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '7', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '7', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '145.0'}
# {'row': '7', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '7', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.039'}
# {'row': '7', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '52.68'}
# {'row': '7', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.96'}
# {'row': '7', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '7', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월27일'}
# {'row': '8', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '8', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '16:12'}
# {'row': '8', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '8', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '149.2'}
# {'row': '8', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '8', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.029'}
# {'row': '8', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '50.77'}
# {'row': '8', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '58.69'}
# {'row': '8', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '10', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월28일'}
# {'row': '10', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '1회'}
# {'row': '10', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '7:01'}
# {'row': '10', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '10', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '180.0'}
# {'row': '10', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '10', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.031'}
# {'row': '10', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '51.15'}
# {'row': '10', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '59.3'}
# {'row': '10', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}
#
#
#
# {'row': '10', 'col': '0', 'colspan': '1', 'rowspan': '3', 'text': '3월28일'}
# {'row': '11', 'col': '1', 'colspan': '1', 'rowspan': '1', 'text': '2회'}
# {'row': '11', 'col': '2', 'colspan': '1', 'rowspan': '1', 'text': '17:21'}
# {'row': '11', 'col': '3', 'colspan': '1', 'rowspan': '1', 'text': '0.5-2.0'}
# {'row': '11', 'col': '4', 'colspan': '1', 'rowspan': '1', 'text': '180.0'}
# {'row': '11', 'col': '5', 'colspan': '1', 'rowspan': '1', 'text': '7k+881.65(종점집수정횡갱)'}
# {'row': '11', 'col': '6', 'colspan': '1', 'rowspan': '1', 'text': '0.038'}
# {'row': '11', 'col': '7', 'colspan': '1', 'rowspan': '1', 'text': '54.83'}
# {'row': '11', 'col': '8', 'colspan': '1', 'rowspan': '1', 'text': '56.16'}
# {'row': '11', 'col': '9', 'colspan': '1', 'rowspan': '1', 'text': '국원물산'}

# %%
serialize_list = []
find_word = ['일시', '시간', 'cm', 'dB', '측정위치']

columns = [item for item in columns if int(item['colspan']) <= 1 and any(word in item['text'] for word in find_word)]
for items in group_list:
    data = {}
    for item in items:
        for column in columns:
            if item['col'] == column['col']:
                data[column['text']] = item['text']
    serialize_list.append(data)

serialize_list
# Out:
# [{'일시': '3월1일',
#   '시간': '7:01',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월1일',
#   '시간': '11:47',
#   '발파진동(cm/s)': '0.209',
#   '진동레벨dB(V)': '72.51',
#   '소음레벨dB(A)': '73.35',
#   '측정위치': '풍전빌딩'},
#  {'일시': '3월1일',
#   '시간': '11:47',
#   '발파진동(cm/s)': '0.141',
#   '진동레벨dB(V)': '71.42',
#   '소음레벨dB(A)': '74.79',
#   '측정위치': '로얄프라자'},
#  {'일시': '3월2일',
#   '시간': '7:02',
#   '발파진동(cm/s)': '0.082',
#   '진동레벨dB(V)': '63.14',
#   '소음레벨dB(A)': '60.99',
#   '측정위치': '국원물산'},
#  {'일시': '3월2일',
#   '시간': '11:51',
#   '발파진동(cm/s)': '0.074',
#   '진동레벨dB(V)': '62.82',
#   '소음레벨dB(A)': '66.59',
#   '측정위치': '풍전빌딩'},
#  {'일시': '3월2일',
#   '시간': '11:51',
#   '발파진동(cm/s)': '0.051',
#   '진동레벨dB(V)': '62.35',
#   '소음레벨dB(A)': '67.68',
#   '측정위치': '로얄프라자'},
#  {'일시': '3월2일',
#   '시간': '18:01',
#   '발파진동(cm/s)': '0.103',
#   '진동레벨dB(V)': '61.62',
#   '소음레벨dB(A)': '66.73',
#   '측정위치': '국원물산'},
#  {'일시': '3월3일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.083',
#   '진동레벨dB(V)': '63.22',
#   '소음레벨dB(A)': '62.45',
#   '측정위치': '국원물산'},
#  {'일시': '3월4일',
#   '시간': '16:25',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월4일',
#   '시간': '18:01',
#   '발파진동(cm/s)': '0.063',
#   '진동레벨dB(V)': '57.19',
#   '소음레벨dB(A)': '58.42',
#   '측정위치': '국원물산'},
#  {'일시': '3월5일',
#   '시간': '7:05',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월5일',
#   '시간': '17:38',
#   '발파진동(cm/s)': '0.117',
#   '진동레벨dB(V)': '62.2',
#   '소음레벨dB(A)': '60.32',
#   '측정위치': '국원물산'},
#  {'일시': '3월6일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.04',
#   '진동레벨dB(V)': '-',
#   '소음레벨dB(A)': '56.03',
#   '측정위치': '국원물산'},
#  {'일시': '3월6일',
#   '시간': '17:05',
#   '발파진동(cm/s)': '0.06',
#   '진동레벨dB(V)': '58.3',
#   '소음레벨dB(A)': '55.55',
#   '측정위치': '국원물산'},
#  {'일시': '3월7일',
#   '시간': '7:00',
#   '발파진동(cm/s)': '0.081',
#   '진동레벨dB(V)': '58.9',
#   '소음레벨dB(A)': '56.14',
#   '측정위치': '국원물산'},
#  {'일시': '3월7일',
#   '시간': '17:19',
#   '발파진동(cm/s)': '0.038',
#   '진동레벨dB(V)': '55.68',
#   '소음레벨dB(A)': '69.16',
#   '측정위치': '국원물산'},
#  {'일시': '3월8일',
#   '시간': '7:21',
#   '발파진동(cm/s)': '0.037',
#   '진동레벨dB(V)': '54.24',
#   '소음레벨dB(A)': '54.27',
#   '측정위치': '국원물산'},
#  {'일시': '3월8일',
#   '시간': '17:36',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월9일',
#   '시간': '9:14',
#   '발파진동(cm/s)': '0.048',
#   '진동레벨dB(V)': '52.73',
#   '소음레벨dB(A)': '52.0',
#   '측정위치': '국원물산'},
#  {'일시': '3월9일',
#   '시간': '17:53',
#   '발파진동(cm/s)': '0.04',
#   '진동레벨dB(V)': '52.0',
#   '소음레벨dB(A)': '58.51',
#   '측정위치': '국원물산'},
#  {'일시': '3월10일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.055',
#   '진동레벨dB(V)': '55.25',
#   '소음레벨dB(A)': '57.77',
#   '측정위치': '국원물산'},
#  {'일시': '3월11일',
#   '시간': '14:57',
#   '발파진동(cm/s)': '0.085',
#   '진동레벨dB(V)': '60.66',
#   '소음레벨dB(A)': '60.56',
#   '측정위치': '국원물산'},
#  {'일시': '3월13일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.053',
#   '진동레벨dB(V)': '57.21',
#   '소음레벨dB(A)': '63.15',
#   '측정위치': '국원물산'},
#  {'일시': '3월13일',
#   '시간': '15:33',
#   '발파진동(cm/s)': '0.152',
#   '진동레벨dB(V)': '66.9',
#   '소음레벨dB(A)': '60.79',
#   '측정위치': '국원물산'},
#  {'일시': '3월13일',
#   '시간': '15:33',
#   '발파진동(cm/s)': '0.152',
#   '진동레벨dB(V)': '66.9',
#   '소음레벨dB(A)': '60.79',
#   '측정위치': '국원물산'},
#  {'일시': '3월14일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.093',
#   '진동레벨dB(V)': '66.03',
#   '소음레벨dB(A)': '61.87',
#   '측정위치': '국원물산'},
#  {'일시': '3월14일',
#   '시간': '15:55',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월14일',
#   '시간': '16:00',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월15일',
#   '시간': '10:57',
#   '발파진동(cm/s)': '0.13',
#   '진동레벨dB(V)': '64.27',
#   '소음레벨dB(A)': '57.97',
#   '측정위치': '국원물산'},
#  {'일시': '3월15일',
#   '시간': '15:16',
#   '발파진동(cm/s)': '0.014',
#   '진동레벨dB(V)': '49.62',
#   '소음레벨dB(A)': '53.62',
#   '측정위치': '국원물산'},
#  {'일시': '3월16일',
#   '시간': '7:04',
#   '발파진동(cm/s)': '0.034',
#   '진동레벨dB(V)': '50.22',
#   '소음레벨dB(A)': '62.92',
#   '측정위치': '국원물산'},
#  {'일시': '3월16일',
#   '시간': '7:10',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월16일',
#   '시간': '17:34',
#   '발파진동(cm/s)': '0.089',
#   '진동레벨dB(V)': '60.05',
#   '소음레벨dB(A)': '60.12',
#   '측정위치': '국원물산'},
#  {'일시': '3월16일',
#   '시간': '17:40',
#   '발파진동(cm/s)': 'N/T',
#   '진동레벨dB(V)': 'N/T',
#   '소음레벨dB(A)': 'N/T',
#   '측정위치': '국원물산'},
#  {'일시': '3월18일',
#   '시간': '18:03',
#   '발파진동(cm/s)': '0.107',
#   '진동레벨dB(V)': '60.34',
#   '소음레벨dB(A)': '59.03',
#   '측정위치': '국원물산'},
#  {'일시': '3월19일',
#   '시간': '11:02',
#   '발파진동(cm/s)': '0.123',
#   '진동레벨dB(V)': '61.02',
#   '소음레벨dB(A)': '61.74',
#   '측정위치': '국원물산'},
#  {'일시': '3월20일',
#   '시간': '7:02',
#   '발파진동(cm/s)': '0.068',
#   '진동레벨dB(V)': '57.93',
#   '소음레벨dB(A)': '58.98',
#   '측정위치': '국원물산'},
#  {'일시': '3월20일',
#   '시간': '18:01',
#   '발파진동(cm/s)': '0.043',
#   '진동레벨dB(V)': '54.16',
#   '소음레벨dB(A)': '58.38',
#   '측정위치': '국원물산'},
#  {'일시': '3월21일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.03',
#   '진동레벨dB(V)': '50.05',
#   '소음레벨dB(A)': '59.36',
#   '측정위치': '국원물산'},
#  {'일시': '3월21일',
#   '시간': '16:00',
#   '발파진동(cm/s)': '0.072',
#   '진동레벨dB(V)': '57.24',
#   '소음레벨dB(A)': '58.46',
#   '측정위치': '국원물산'},
#  {'일시': '3월22일',
#   '시간': '8:51',
#   '발파진동(cm/s)': '0.048',
#   '진동레벨dB(V)': '56.89',
#   '소음레벨dB(A)': '58.11',
#   '측정위치': '국원물산'},
#  {'일시': '3월22일',
#   '시간': '18:36',
#   '발파진동(cm/s)': '0.055',
#   '진동레벨dB(V)': '56.74',
#   '소음레벨dB(A)': '57.59',
#   '측정위치': '국원물산'},
#  {'발파진동(cm/s)': '0.055',
#   '진동레벨dB(V)': '56.74',
#   '소음레벨dB(A)': '57.59',
#   '일시': '3월23일',
#   '시간': '10:45',
#   '측정위치': '국원물산'},
#  {'일시': '3월24일',
#   '시간': '7:02',
#   '발파진동(cm/s)': '0.039',
#   '진동레벨dB(V)': '56.96',
#   '소음레벨dB(A)': '59.09',
#   '측정위치': '국원물산'},
#  {'일시': '3월25일',
#   '시간': '11:29',
#   '발파진동(cm/s)': '0.07',
#   '진동레벨dB(V)': '61.38',
#   '소음레벨dB(A)': '63.68',
#   '측정위치': '국원물산'},
#  {'일시': '3월26일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.03',
#   '진동레벨dB(V)': '53.8',
#   '소음레벨dB(A)': '56.92',
#   '측정위치': '국원물산'},
#  {'일시': '3월26일',
#   '시간': '16:11',
#   '발파진동(cm/s)': '0.027',
#   '진동레벨dB(V)': '52.9',
#   '소음레벨dB(A)': '57.13',
#   '측정위치': '국원물산'},
#  {'일시': '3월27일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.039',
#   '진동레벨dB(V)': '52.68',
#   '소음레벨dB(A)': '56.96',
#   '측정위치': '국원물산'},
#  {'일시': '3월27일',
#   '시간': '16:12',
#   '발파진동(cm/s)': '0.029',
#   '진동레벨dB(V)': '50.77',
#   '소음레벨dB(A)': '58.69',
#   '측정위치': '국원물산'},
#  {'일시': '3월28일',
#   '시간': '7:01',
#   '발파진동(cm/s)': '0.031',
#   '진동레벨dB(V)': '51.15',
#   '소음레벨dB(A)': '59.3',
#   '측정위치': '국원물산'},
#  {'일시': '3월28일',
#   '시간': '17:21',
#   '발파진동(cm/s)': '0.038',
#   '진동레벨dB(V)': '54.83',
#   '소음레벨dB(A)': '56.16',
#   '측정위치': '국원물산'}]

# %%
import pandas as pd

# pandas DataFrame으로 변환
df = pd.DataFrame(serialize_list)

# 계측 위치별로 데이터 프레임 분류
locations = df['측정위치'].unique()  # 계측 위치별 고유값을 찾음
print(df['측정위치'].unique())

# 각 위치별 데이터 프레임을 딕셔너리에 저장
dfs = {}
for location in locations:
    dfs[location] = df[df['측정위치'] == location]

# 결과 확인
# 예시: 과천지식정보타운 위치의 데이터 프레임 출력
print(dfs['국원물산'])
# Out:
# ['국원물산' '풍전빌딩' '로얄프라자']
#        일시     시간 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  측정위치
# 0    3월1일   7:01        N/T       N/T       N/T  국원물산
# 3    3월2일   7:02      0.082     63.14     60.99  국원물산
# 6    3월2일  18:01      0.103     61.62     66.73  국원물산
# 7    3월3일   7:01      0.083     63.22     62.45  국원물산
# 8    3월4일  16:25        N/T       N/T       N/T  국원물산
# 9    3월4일  18:01      0.063     57.19     58.42  국원물산
# 10   3월5일   7:05        N/T       N/T       N/T  국원물산
# 11   3월5일  17:38      0.117      62.2     60.32  국원물산
# 12   3월6일   7:01       0.04         -     56.03  국원물산
# 13   3월6일  17:05       0.06      58.3     55.55  국원물산
# 14   3월7일   7:00      0.081      58.9     56.14  국원물산
# 15   3월7일  17:19      0.038     55.68     69.16  국원물산
# 16   3월8일   7:21      0.037     54.24     54.27  국원물산
# 17   3월8일  17:36        N/T       N/T       N/T  국원물산
# 18   3월9일   9:14      0.048     52.73      52.0  국원물산
# 19   3월9일  17:53       0.04      52.0     58.51  국원물산
# 20  3월10일   7:01      0.055     55.25     57.77  국원물산
# 21  3월11일  14:57      0.085     60.66     60.56  국원물산
# 22  3월13일   7:01      0.053     57.21     63.15  국원물산
# 23  3월13일  15:33      0.152      66.9     60.79  국원물산
# 24  3월13일  15:33      0.152      66.9     60.79  국원물산
# 25  3월14일   7:01      0.093     66.03     61.87  국원물산
# 26  3월14일  15:55        N/T       N/T       N/T  국원물산
# 27  3월14일  16:00        N/T       N/T       N/T  국원물산
# 28  3월15일  10:57       0.13     64.27     57.97  국원물산
# 29  3월15일  15:16      0.014     49.62     53.62  국원물산
# 30  3월16일   7:04      0.034     50.22     62.92  국원물산
# 31  3월16일   7:10        N/T       N/T       N/T  국원물산
# 32  3월16일  17:34      0.089     60.05     60.12  국원물산
# 33  3월16일  17:40        N/T       N/T       N/T  국원물산
# 34  3월18일  18:03      0.107     60.34     59.03  국원물산
# 35  3월19일  11:02      0.123     61.02     61.74  국원물산
# 36  3월20일   7:02      0.068     57.93     58.98  국원물산
# 37  3월20일  18:01      0.043     54.16     58.38  국원물산
# 38  3월21일   7:01       0.03     50.05     59.36  국원물산
# 39  3월21일  16:00      0.072     57.24     58.46  국원물산
# 40  3월22일   8:51      0.048     56.89     58.11  국원물산
# 41  3월22일  18:36      0.055     56.74     57.59  국원물산
# 42  3월23일  10:45      0.055     56.74     57.59  국원물산
# 43  3월24일   7:02      0.039     56.96     59.09  국원물산
# 44  3월25일  11:29       0.07     61.38     63.68  국원물산
# 45  3월26일   7:01       0.03      53.8     56.92  국원물산
# 46  3월26일  16:11      0.027      52.9     57.13  국원물산
# 47  3월27일   7:01      0.039     52.68     56.96  국원물산
# 48  3월27일  16:12      0.029     50.77     58.69  국원물산
# 49  3월28일   7:01      0.031     51.15      59.3  국원물산
# 50  3월28일  17:21      0.038     54.83     56.16  국원물산
