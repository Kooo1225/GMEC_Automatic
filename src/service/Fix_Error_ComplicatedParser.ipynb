# %%
import re, clipboard, uuid
import numpy as np
from itertools import takewhile

import pandas as pd

from src.service.ParseService import ParseService


class ComplicatedParser(ParseService):
    def __init__(self):
        self.title = ['발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)']
        self.blast_pattern = None

    def extract_columns(self, items_list):
        columns = list(takewhile(lambda x: not re.match(r'\d+월\d+일', x), items_list))
        if '발파패턴' in columns:
            self.blast_pattern = True
        else:
            self.blast_pattern = False
            
        return [i for i in items_list if i not in columns]

    def conversion_error_value(self, non_columns_list):
        conversion_error_list = []

        for item in non_columns_list:
            if item == "계측기오류":
                conversion_error_list.extend([np.nan, np.nan, np.nan])
            elif re.match(r'n/*?t', item, re.IGNORECASE) or item == "-":
                conversion_error_list.append(np.nan)
            else:
                conversion_error_list.append(item)

        return conversion_error_list

    def delete_other_value(self, conversion_error_list):
        filtered_list = []
        skip_count = 0

        for index in range(len(conversion_error_list)):
            try:
                if skip_count > 0:
                    skip_count -= 1
                    continue
                elif conversion_error_list[index] == '계' or conversion_error_list[index - 1] == '계':
                    continue
                elif re.match(r'\d+:\d+', conversion_error_list[index]) and re.match(r'\d+회', conversion_error_list[index - 1]):
                    print(conversion_error_list[index], end=" ")
                    filtered_list.append(conversion_error_list[index])
                    print(self.blast_pattern)
                    if self.blast_pattern:
                        skip_count += 4
                    else:
                        skip_count += 3
                else:
                    filtered_list.append(conversion_error_list[index])
            except TypeError as e:
                filtered_list.append(conversion_error_list[index])

        return filtered_list

    def classification_by_date(self, filtered_list):
        section = []
        current_date_section = []

        for i in filtered_list:
            try:
                if re.match(r'\d+월\d+일', i) and current_date_section:
                    section.append(current_date_section)
                    current_date_section = []
                current_date_section.append(i)
            except TypeError as t:
                current_date_section.append(i)

        if current_date_section:
            section.append(current_date_section)

        return section

    def extract_location(self, classification_list):
        location_list = []
        data_count = 0

        for items in classification_list:
            for item in items:
                try:
                    if re.match(r'\d+\.\d+', item) or item is np.nan:
                        data_count += 1
                    elif data_count >= 3:
                        location_list.append(item)
                        data_count = 0
                except TypeError as t:
                    data_count += 1

        return list(set(location_list))

    def get_dict(self, classification_list, location_list):
        result = {}
        value = []

        date_key, time_key, location_key = None, None, None

        for item in classification_list:
            for x, i in enumerate(item):
                if isinstance(i, float):
                    i = str(i)
                if re.match(r'\d+월\d+일', i):
                    date_key = i
                elif re.match(r'\d+회', i):
                    count_key = i
                elif re.match(r'\d+:\d+', i):
                    time_key = i
                elif i not in location_list:
                    value.append(i)
                elif i in location_list:
                    location_key = i
                    unique_key = uuid.uuid4()
                    result[location_key] = {} if location_key not in result else result[location_key]
                    result[location_key][unique_key] = {'일시': f'{date_key} {time_key}'}
                    print(value, len(value))
                    for j in range(len(self.title)):
                        try:
                            tmp = float(value[j])
                        except ValueError:
                            tmp = np.nan
                        except IndexError:
                            print(value)
                        finally:
                            result[location_key][unique_key][self.title[j]] = tmp
                    value = []

        return result

# %%
test_parser = ComplicatedParser()
table_list = list(filter(lambda x: x, clipboard.paste().replace("\r\n", " ").split(" ")))

print(table_list)
# Out:
# ['일시', '발파횟수', '시간', '장약량(kg)', '발파위치', '발파진동및소음측정치(max값)', '지발당장약량', '총장약량', 'STA', '발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)', '측정위치', '2월1일', '1회', '7:01', '1.6-2.0', '310.0', '7k+751.00~753.50(종점)', '0.123', '64.92', '66.36', '안산천주교회', '2회', '11:31', '1.6-2.0', '160.0', '5k+184.15~182.90(시점)', 'N/T', 'N/T', 'N/T', '풍전빌딩(현장)', '0.105', '64.92', '60.95', '주공1단지아파트110동', '0.127', '68.22', '74.8', '로얄프라자', '3회', '18:16', '1.6-2.0', '283.0', '7k+753.80~756.00(종점)', '0.161', '60.58', '63.16', '안산천주교회', '계', '753.0', '2월2일', '1회', '7:00', '1.6-2.0', '310.0', '7k+756.00~758.50(종점)', '0.122', '68.41', '69.03', '안산천주교회', '2회', '10:42', '1.6-2.0', '160.0', '5k+181.65~180.40(시점)', '0.048', '54.74', '55.37', '풍전빌딩(현장)', '0.071', '60.42', '61.22', '주공1단지아파트110동', 'N/T', 'N/T', 'N/T', '로얄프라자', '3회', '18:17', '1.6-2.0', '306.0', '7k+758.50~761.00(종점)', '0.046', '56.69', '59.07', '안산천주교회', '계', '776.0', '2월3일', '1회', '7:01', '1.6-2.0', '315.0', '7k+759.75~762.25(종점)', '0.059', '59.6', '61.86', '안산천주교회', '2회', '10:16', '1.6-2.0', '165.0', '5k+179.15~177.90(시점)', '0.083', '58.5', '64.24', '풍전빌딩(현장)', '0.092', '62.41', '60.64', '주공1단지아파트110동', 'N/T', 'N/T', 'N/T', '로얄프라자', '3회', '17:30', '1.6-2.0', '304.0', '7k+762.25~764.75(종점)', '0.057', '58.64', '60.59', '안산천주교회', '계', '784.0', '2월4일', '1회', '7:25', '1.6-2.0', '335.0', '7k+764.75~767.25(종점)', '0.05', '57.76', '61.53', '안산천주교회', '2회', '11:04', '1.6-2.0', '195.0', '5k+176.65~175.40(시점)', '0.07', '59.13', '53.8', '풍전빌딩(현장)', '0.113', '61.03', '61.39', '주공1단지아파트110동', 'N/T', 'N/T', 'N/T', '로얄프라자', '계', '530.0', '2월5일', '1회', '12:15', '1.6-2.0', '345.0', '7k+769.75~772.25(종점)', 'N/T', 'N/T', 'N/T', '안산천주교회', '2회', '16:24', '1.6-2.0', '160.0', '5k+174.15~172.90(시점)', '0.081', '60.05', '54.81', '풍전빌딩(현장)', '0.085', '61.6', '63.85', '주공1단지아파트110동', '0.185', '68.98', '79.14', '로얄프라자', '계', '505.0', '일시', '발파횟수', '시간', '장약량(kg)', '발파위치', '발파진동및소음측정치(max값)', '지발당장약량', '총장약량', 'STA', '발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)', '측정위치', '2월6일', '1회', '7:00', '1.6-2.0', '325.0', '7k+771.25~774.25(종점)', '0.062', '59.16', '64.92', '안산천주교회', '2회', '10:41', '1.6-2.0', '160.0', '5k+172.90~171.65(시점)', 'N/T', 'N/T', 'N/T', '풍전빌딩(현장)', 'N/T', 'N/T', 'N/T', '주공1단지아파트110동', '0.125', '66.55', '72.45', '로얄프라자', '3회', '17:31', '1.6-2.0', '259.0', '7k+774.25~776.75(종점)', '0.081', '70.71', '59.41', '안산천주교회', '계', '744.0', '2월7일', '1회', '7:00', '1.6-2.0', '295.0', '7k+779.75~782.25(종점)', '0.129', '65.67', '65.5', '안산천주교회', '2회', '9:52', '1.6-2.0', '160.0', '5k+170.40~169.15(시점)', '0.107', '62.67', '56.07', '풍전빌딩(현장)', 'N/T', 'N/T', 'N/T', '주공1단지아파트110동', '0.088', '66.68', '71.82', '로얄프라자', '3회', '17:24', '1.6-2.0', '260.0', '7k+782.25~784.75(종점)', '0.057', '58.12', '59.57', '안산천주교회', '계', '715.0', '2월13일', '1회', '10:12', '1.6-2.0', '292.0', '7k+784.75~787.25(종점)', 'N/T', 'N/T', 'N/T', '안산천주교회', '2회', '17:21', '1.6-2.0', '160.0', '5k+167.90~166.65(시점)', '0.103', '61.63', '64.13', '풍전빌딩(현장)', '0.055', '55.92', '55.86', '주공1단지아파트110동', '0.096', '66.37', '71.92', '로얄프라자', '계', '452.0', '2월14일', '1회', '7:00', '1.6-2.0', '300.0', '7k+789.75~792.25(종점)', '0.101', '58.97', '64.51', '안산천주교회', '2회', '9:55', '1.6-2.0', '160.0', '5k+166.65~165.40(시점)', '0.093', '60.41', '57.29', '풍전빌딩(현장)', '0.045', '58.15', '58.35', '주공1단지아파트110동', '0.097', '64.22', '70.47', '로얄프라자', '3회', '18:01', '1.6-2.0', '260.0', '7k+792.25~794.75(종점)', '0.082', '59.54', '64.04', '안산천주교회', '계', '720.0', '2월15일', '1회', '7:42', '1.6-2.0', '195.0', '5k+164.15~162.90(시점)', '0.154', '64.64', '57.59', '풍전빌딩(현장)', '0.053', '58.43', '60.33', '주공1단지아파트110동', '0.157', '70.54', '72.93', '로얄프라자', '2회', '17:49', '1.6-2.0', '245.0', '7k+794.75~797.25(종점)', '0.137', '63.86', '62.79', '안산천주교회', '계', '440.0', '일시', '발파횟수', '시간', '장약량(kg)', '발파위치', '발파진동및소음측정치(max값)', '지발당장약량', '총장약량', 'STA', '발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)', '측정위치', '2월16일', '1회', '7:00', '1.6-2.0', '300.0', '7k+797.25~799.75(종점)', '0.208', '68.43', '62.08', '안산천주교회', '2회', '11:21', '1.6-2.0', '195.0', '5k+162 ...

# %%
non_columns_list = test_parser.extract_columns(table_list)

print(non_columns_list)
# Out:
종점)', '0.057', '58.12', '59.57', '안산천주교회', '계', '715.0', '2월13일', '1회', '10:12', '1.6-2.0', '292.0', '7k+784.75~787.25(종점)', 'N/T', 'N/T', 'N/T', '안산천주교회', '2회', '17:21', '1.6-2.0', '160.0', '5k+167.90~166.65(시점)', '0.103', '61.63', '64.13', '풍전빌딩(현장)', '0.055', '55.92', '55.86', '주공1단지아파트110동', '0.096', '66.37', '71.92', '로얄프라자', '계', '452.0', '2월14일', '1회', '7:00', '1.6-2.0', '300.0', '7k+789.75~792.25(종점)', '0.101', '58.97', '64.51', '안산천주교회', '2회', '9:55', '1.6-2.0', '160.0', '5k+166.65~165.40(시점)', '0.093', '60.41', '57.29', '풍전빌딩(현장)', '0.045', '58.15', '58.35', '주공1단지아파트110동', '0.097', '64.22', '70.47', '로얄프라자', '3회', '18:01', '1.6-2.0', '260.0', '7k+792.25~794.75(종점)', '0.082', '59.54', '64.04', '안산천주교회', '계', '720.0', '2월15일', '1회', '7:42', '1.6-2.0', '195.0', '5k+164.15~162.90(시점)', '0.154', '64.64', '57.59', '풍전빌딩(현장)', '0.053', '58.43', '60.33', '주공1단지아파트110동', '0.157', '70.54', '72.93', '로얄프라자', '2회', '17:49', '1.6-2.0', '245.0', '7k+794.75~797.25(종점)', '0.137', '63.86', '62.79', '안산천주교회', '계', '440.0', '2월16일', '1회', '7:00', '1.6-2.0', '300.0', '7k+797.25~799.75(종점)', '0.208', '68.43', '62.08', '안산천주교회', '2회', '11:21', '1.6-2.0', '195.0', '5k+162.90~161.65(시점)', '0.232', '69.72', '57.03', '주공1단지110동(현장)', '0.091', '59.52', '62.23', '주공1단지아파트110동', '0.156', '67.63', '76.16', '로얄프라자', '3회', '17:05', '1.6-2.0', '274.0', '7k+799.75~802.25(종점)', '0.124', '64.39', '67.44', '안산천주교회', '계', '769.0', '2월17일', '1회', '7:00', '1.6-2.0', '275.0', '7k+802.25~804.75(종점)', '0.042', '55.65', '63.54', '안산천주교회', '2회', '10:14', '1.6-2.0', '185.0', '5k+160 ...

# %%
conversion_error_list = test_parser.conversion_error_value(non_columns_list)

print(conversion_error_list)
# Out:
# ['2월1일', '1회', '7:01', '1.6-2.0', '310.0', '7k+751.00~753.50(종점)', '0.123', '64.92', '66.36', '안산천주교회', '2회', '11:31', '1.6-2.0', '160.0', '5k+184.15~182.90(시점)', nan, nan, nan, '풍전빌딩(현장)', '0.105', '64.92', '60.95', '주공1단지아파트110동', '0.127', '68.22', '74.8', '로얄프라자', '3회', '18:16', '1.6-2.0', '283.0', '7k+753.80~756.00(종점)', '0.161', '60.58', '63.16', '안산천주교회', '계', '753.0', '2월2일', '1회', '7:00', '1.6-2.0', '310.0', '7k+756.00~758.50(종점)', '0.122', '68.41', '69.03', '안산천주교회', '2회', '10:42', '1.6-2.0', '160.0', '5k+181.65~180.40(시점)', '0.048', '54.74', '55.37', '풍전빌딩(현장)', '0.071', '60.42', '61.22', '주공1단지아파트110동', nan
', '60.41', '57.29', '풍전빌딩(현장)', '0.045', '58.15', '58.35', '주공1단지아파트110동', '0.097', '64.22', '70.47', '로얄프라자', '3회', '18:01', '1.6-2.0', '260.0', '7k+792.25~794.75(종점)', '0.082', '59.54', '64.04', '안산천주교회', '계', '720.0', '2월15일', '1회', '7:42', '1.6-2.0', '195.0', '5k+164.15~162.90(시점)', '0.154', '64.64', '57.59', '풍전빌딩(현장)', '0.053', '58.43', '60.33', '주공1단지아파트110동', '0.157', '70.54', '72.93', '로얄프라자', '2회', '17:49', '1.6-2.0', '245.0', '7k+794.75~797.25(종점)', '0.137', '63.86', '62.79', '안산천주교회', '계', '440.0', '2월16일', '1회', '7:00', '1.6-2.0', '300.0', '7k+797.25~799.75(종점)', '0.208', '68.43', '62.08', '안산천주교회', '2회', '11:21', '1.6-2.0', '195.0', '5k+162.90~161.65(시점)', '0.232', '69.72', '57.03', '주공1단지110동(현장)', '0.091', '59.52', '62.23', '주공1단지아파트110동', '0.156', '67.63', '76.16', '로얄프라자', '3회', '17:05', '1.6-2.0', '274.0', '7k+799.75~802.25(종점)', '0.124', '64.39', '67.44', '안산천주교회', '계', '769.0', '2월17일', '1회', '7:00', '1.6-2.0', '275.0', '7k+802.25~804.75(종점)', '0.042', '55.65', '63.54', '안산천주교회', '2회', '10:14', '1.6-2.0', '185.0', '5k+160.40~159.15(시점)', '0.046', '55.99', '54.73', '주공1단지110동 ...

# %%
filtered_list = test_parser.delete_other_value(conversion_error_list)

print(filtered_list)
# Out:
# 7:01 False
# 11:31 False
# 18:16 False
# 7:00 False
# 10:42 False
# 18:17 False
# 7:01 False
# 10:16 False
# 17:30 False
# 7:25 False
# 11:04 False
# 12:15 False
# 16:24 False
# 7:00 False
# 10:41 False
# 17:31 False
# 7:00 False
# 9:52 False
# 17:24 False
# 10:12 False
# 17:21 False
# 7:00 False
# 9:55 False
# 18:01 False
# 7:42 False
# 17:49 False
# 7:00 False
# 11:21 False
# 17:05 False
# 7:00 False
# 10:14 False
# 17:04 False
# 7:00 False
# 10:11 False
# 12:34 False
# 16:30 False
# 7:00 False
# 10:37 False
# 7:00 False
# 10:40 False
# 7:01 False
# 10:35 False
# 17:35 False
# 7:00 False
# 10:20 False
# 16:45 False
# 7:01 False
# 10:00 False
# 17:37 False
# 7:15 False
# 11:36 False
# 12:00 False
# 16:59 False
# 7:01 False
# 12:20 False
# 18:30 False
# 7:01 False
# 18:24 False
# 7:11 False
# 11:51 False
# 17:40 False
# ['2월1일', '1회', '7:01', '0.123', '64.92', '66.36', '안산천주교회', '2회', '11:31', nan, nan, nan, '풍전빌딩(현장)', '0.105', '64.92', '60.95', '주공1단지아파트110동', '0.127', '68.22', '74.8', '로얄프라자', '3회', '18:16', '0.161', '60.58', '63.16', '안산천주교회', '2월2일', '1회', '7:00', '0.122', '68.41', '69.03', '안산천주교회', '2회', '10:42', '0.048', '54.74', '55.37', '풍전빌딩(현장)', '0.071', '60.42', '
천주교회', '2회', '10:11', '0.156', '66.81', '58.9', '주공1단지110동(현장)', '0.055', '56.67', '60.24', '주공1단지아파트110동', '0.055', '56.67', '60.24', '로얄프라자', '2월19일', '1회', '12:34', '0.092', '59.44', '66.26', '안산천주교회', '2회', '16:30', '0.053', '56.79', '54.66', '풍전빌딩(현장)', '0.067', '63.65', '65.21', '풍전빌딩(자동화계측)', '0.09', '65.22', '70.87', '로얄프라자', '2월20일', '1회', '7:00', '0.128', '67.27', '63.47', '안산천주교회', '2회', '10:37', nan, nan, nan, '풍전빌딩(현장)', '0.058', '63.16', '62.38', '풍전빌딩(자동화계측)', '0.065', '62.89', '68.15', '로얄프라자', '2월21일', '1회', '7:00', nan, nan, nan, '안산천주교회', '2회', '10:40', '0.231', '62.25', '35.52', '풍전빌딩(현장)', '0.044', '57.5', '62.27', '풍전빌딩(자동화계측)', '0.046', '60.47', '68.46', '로얄프라자', '2월22일', '1회', '7:01', '0.233', '70.53', '62.49', '안산천주교회', '2회', '10:35', nan, nan, nan, '풍전빌딩(현장)', '0.069', '60.53', '63.09', '풍전빌딩(자동화계측)', '0.072', '63.8', '68.34', '로얄프라자', '3회', '17:35', '0.042', '56.89', '59.88', '국원물산', '2월23일', '1회', '7:00', '0.057', '57.89', '63.58', '국원물산', '2회', '10:20', nan, nan, nan, '풍전빌딩(현장)', '0.027', '55.96', '57.84', '풍전빌딩(자동화계측)', '0.033', '57.98', '64.59', '로얄프라자', '3회', '16:45', '0.075', '56.83', '65.9', '국원물산', '2월24일', '1회', '7:01', '0.147', '59.45', '68.29', '국원물산', '2회', '10:00', '0.073', '60.51', '64.77', '풍전빌딩(자동화계측)', '0.065', '64.64', '68.71', '로얄프라자', '3회', '17:37', nan, nan, na ...

# %%
classification_list = test_parser.classification_by_date(filtered_list)

print(classification_list)
# Out:
# [['2월1일', '1회', '7:01', '0.123', '64.92', '66.36', '안산천주교회', '2회', '11:31', nan, nan, nan, '풍전빌딩(현장)', '0.105', '64.92', '60.95', '주공1단지아파트110동', '0.127', '68.22', '74.8', '로얄프라자', '3회', '18:16', '0.161', '60.58', '63.16', '안산천주교회'], ['2월2일', '1회', '7:00', '0.122', '68.41', '69.03', '안산천주교회', '2회', '10:42', '0.048', '54.74', '55.37', '풍전빌딩(현장)', '0.071', '60.42', '61.22', '주공1단지아파트110동', nan, nan, nan, '로얄프라자', '3회', '18:17', '0.046', '56.69', '59.07', '안산천주교회'], ['2월3일', '1회', '7:01', '0.059', '59.6', '61.86', '안산천주교회', '2회', '10:16', '0.083', '58.5', '64.24', '풍전빌딩(현장)', '0.092', '62.41', '60.64', '주공1단지아파트110동', nan, nan, nan, '로얄프라자', '3회', '17:30', '0.057', '58.64', '60.59', '안산천주교회'], ['2월4일', '1회', '7:25', '0.05', '57.76', '61.53', '안산천주교회', '2회', '11:04', '0.07', '59.13', '53.8', '풍전빌딩(현장)', '0.113', '61.03', '61.39', '주공1단지아파트110동', nan, nan
62.38', '풍전빌딩(자동화계측)', '0.065', '62.89', '68.15', '로얄프라자'], ['2월21일', '1회', '7:00', nan, nan, nan, '안산천주교회', '2회', '10:40', '0.231', '62.25', '35.52', '풍전빌딩(현장)', '0.044', '57.5', '62.27', '풍전빌딩(자동화계측)', '0.046', '60.47', '68.46', '로얄프라자'], ['2월22일', '1회', '7:01', '0.233', '70.53', '62.49', '안산천주교회', '2회', '10:35', nan, nan, nan, '풍전빌딩(현장)', '0.069', '60.53', '63.09', '풍전빌딩(자동화계측)', '0.072', '63.8', '68.34', '로얄프라자', '3회', '17:35', '0.042', '56.89', '59.88', '국원물산'], ['2월23일', '1회', '7:00', '0.057', '57.89', '63.58', '국원물산', '2회', '10:20', nan, nan, nan, '풍전빌딩(현장)', '0.027', '55.96', '57.84', '풍전빌딩(자동화계측)', '0.033', '57.98', '64.59', '로얄프라자', '3회', '16:45', '0.075', '56.83', '65.9', '국원물산'], ['2월24일', '1회', '7:01', '0.147', '59.45', '68.29', '국원물산', '2회', '10:00', '0.073', '60.51', '64.77', '풍전빌딩(자동화계측)', '0.065', '64.64', '68.71', ...

# %%
location_list = test_parser.extract_location(classification_list)

print(location_list)
# Out:
# ['안산천주교회', '주공1단지110동(현장)', '로얄프라자', '국원물산', '주공1단지아파트110동', '풍전빌딩(자동화계측)', '풍전빌딩(현장)']

# %%
result_dict = test_parser.get_dict(classification_list, location_list)

print(result_dict)
# Out:
# ['0.123', '64.92', '66.36'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.105', '64.92', '60.95'] 3
# ['0.127', '68.22', '74.8'] 3
# ['0.161', '60.58', '63.16'] 3
# ['0.122', '68.41', '69.03'] 3
# ['0.048', '54.74', '55.37'] 3
# ['0.071', '60.42', '61.22'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.046', '56.69', '59.07'] 3
# ['0.059', '59.6', '61.86'] 3
# ['0.083', '58.5', '64.24'] 3
# ['0.092', '62.41', '60.64'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.057', '58.64', '60.59'] 3
# ['0.05', '57.76', '61.53'] 3
# ['0.07', '59.13', '53.8'] 3
# ['0.113', '61.03', '61.39'] 3
# ['nan', 'nan', 'nan'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.081', '60.05', '54.81'] 3
# ['0.085', '61.6', '63.85'] 3
# ['0.185', '68.98', '79.14'] 3
# ['0.062', '59.16', '64.92'] 3
# ['nan', 'nan', 'nan'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.125', '66.55', '72.45'] 3
# ['0.081', '70.71', '59.41'] 3
# ['0.129', '65.67', '65.5'] 3
# ['0.107', '62.67', '56.07'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.088', '66.68', '71.82'] 3
# ['0.057', '58.12', '59.57'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.103', '61.63', '64.13'] 3
# ['0.055', '55.92', '55.86'] 3
# ['0.096', '66.37', '71.92'] 3
# ['0.101', '58.97', '64.51'] 3
# ['0.093', '60.41', '57.29'] 3
# ['0.045', '58.15', '58.35'] 3
# ['0.097', '64.22', '70.47'] 3
# ['0.082', '59.54', '64.04'] 3
# ['0.154', '64.64', '57.59'] 3
# ['0.053', '58.43', '60.33'] 3
# ['0.157', '70.54', '72.93'] 3
# ['0.137', '63.86', '62.79'] 3
# ['0.208', '68.43', '62.08'] 3
# ['0.232', '69.72', '57.03'] 3
# ['0.091', '59.52', '62.23'] 3
# ['0.156', '67.63', '76.16'] 3
# ['0.124', '64.39', '67.44'] 3
# ['0.042', '55.65', '63.54'] 3
# ['0.046', '55.99', '54.73'] 3
# ['0.055', '57.56', '57.95'] 3
# ['0.101', '66.23', '71.74'] 3
# ['0.187', '64.8', '62.98'] 3
# ['0.07', '56.33', '65.84'] 3
# ['0.156', '66.81', '58.9'] 3
# ['0.055', '56.67', '60.24'] 3
# ['0.055', '56.67', '60.24'] 3
# ['0.092', '59.44', '66.26'] 3
# ['0.053', '56.79', '54.66'] 3
# ['0.067', '63.65', '65.21'] 3
# ['0.09', '65.22', '70.87'] 3
# ['0.128', '67.27', '63.47'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.058', '63.16', '62.38'] 3
# ['0.065', '62.89', '68.15'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.231', '62.25', '35.52'] 3
# ['0.044', '57.5', '62.27'] 3
# ['0.046', '60.47', '68.46'] 3
# ['0.233', '70.53', '62.49'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.069', '60.53', '63.09'] 3
# ['0.072', '63.8', '68.34'] 3
# ['0.042', '56.89', '59.88'] 3
# ['0.057', '57.89', '63.58'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.027', '55.96', '57.84'] 3
# ['0.033', '57.98', '64.59'] 3
# ['0.075', '56.83', '65.9'] 3
# ['0.147', '59.45', '68.29'] 3
# ['0.073', '60.51', '64.77'] 3
# ['0.065', '64.64', '68.71'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.353', '68.24', '60.38'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.115', '69.63', '71.83'] 3
# ['0.044', '51.41', '58.08'] 3
# ['0.032', '49.68', '61.86'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.042', '60.06', '59.88'] 3
# ['0.087', '63.43', '63.77'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.043', '59.02', '62.61'] 3
# ['0.1', '60.78', '58.5'] 3
# ['nan', 'nan', 'nan'] 3
# ['0.037', '60.68', '61.87'] 3
# ['0.049', '57.8', '56.17'] 3
# ['0.069', '62.68', '62.06'] 3
# ['0.124', '68.09', '66.09'] 3
# ['0.098', '66.04', '71.27'] 3
# ['0.127', '62.59', '59.79'] 3
# {'안산천주교회': {UUID('dc108504-257f-42c2-b711-b7bcd4d25c83'): {'일시': '2월1일 7:01', '발파진동(cm/s)': 0.123, '진동레벨dB(V)': 64.92, '소음레벨dB(A)': 66.36}, UUID('daae29e3-4ea8-40aa-8206-b7ea61778728'): {'일시': '2월1일 18:16', '발파진동(cm/s)': 0.161, '진동레벨dB(V)': 60.58, '소음레벨dB(A)': 63.16}, UUID('150497dc-38cc-4014-8c14-9241b3ac356b'): {'일시': '2월2일 7:00', '발파진동(cm/s)': 0.122, '진동레벨dB(V)': 68.41, '소음레벨dB(A)': 69.03}, UUID('cff9375f-304c-40c0-a236-dfc7a389120e'): {'일시': '2월2일 18:17', '발파진동(cm/s)': 0.046, '진동레벨dB(V)': 56.69, '소음레벨dB(A)': 59.07}, UUID('45733a35-5f0d-43d7-918c-f56aafac5e13'): {'일시': '2월3일 7:01', '발파진동(cm/s)': 0.059, '진동레벨dB(V)': 59.6, '소음레벨dB(A)': 61.86}, UUID('439507a7-db47-4353-9ce9-209c6f48510e'): {'일시': '2월3일 17:30', '발파진동(cm/s)': 0.057, '진동레벨dB(V)': 58.64, '소음레벨dB(A)': 60.59}, UUID('d687dbe7-4777-4776-b04c-c7b2f0772f6d'): {'일시': '2월4일 7:25', '발파진동(cm/s)': 0.05, '진동레벨dB(V)': 57.76, '소음레벨dB(A)': 61.53}, UUID('4ef2b649-a70a-4c7d-9fa1-a092f2fc2049'): {'일시': '2월5일 12:15', '발파진동(cm/s)': nan, '진동레벨dB(V)': nan, '소음레벨dB(A)': nan}, UUID('d9c56105-0d1b-4d6a-a2f1-7d108477b672'): {'일시': '2월6일 7:00', '발파진동(cm/s)': 0.062, '진동레벨dB(V)': 59.16, '소음레벨dB(A)': 64.92}, UUID('60963279-cb61-4a35-9658-d62966e7bf48'): {'일시': '2월6일 17:31', '발파진동(cm/s)': 0.081, '진동레벨dB(V)': 70.71, '소음레벨dB(A)': 59.41}, UUID('a7b86ca3-cffc-4894-b7b4-c9304d8d6818'): {'일시': '2월7일 7:00', '발파진동(cm/s)': 0.129, '진동레벨dB(V)': 65.67, '소음레벨dB(A)': 65.5}, UUID('b94973ef-de21-49e0-baab-208684da263b'): {'일시': '2월7일 17:24', '발파진동(cm/s)': 0.057, '진동레벨dB(V)': 58.12, '소음레벨dB(A)': 59.57}, UUID('b701d9e5-ff2e-4b1b-b75e-52707014045c'): {'일시': '2월13일 10:12', '발파진동(cm/s)': nan, '진동레벨dB(V)': nan, '소음레벨dB(A)': nan}, UUID('84b7335e-cc5a-4f30-873c-91b4e6959421'): {'일시': '2월14일 7:00', '발파진동(cm/s)': 0.101, '진동레벨dB(V)': 58.97, '소음레벨dB(A)': 64.51}, UUID('47f1096d-c067-4798-b511-95576936c8e6'): {'일시': '2월14일 18:01', '발파진동(cm/s)': 0.082, '진동레벨dB(V)': 59.54, '소음레벨dB(A)': 64.04}, UUID('59741bf4-b060-4218-9139-d6a84b448084'): {'일시': '2월15일 17:49', '발파진동(cm/s)': 0.137, '진동레벨dB(V)': 63.86, '소음레벨dB(A)': 62.79}, UUID('75f56573-cfd9-4e5b-8919-1b84751e0b50'): {'일시': '2월16일 7:00', '발파진동(cm/s)': 0.208, '진동레벨dB(V)': 68.43, '소음레벨dB(A)': 62.08}, UUID('9460f86e-3611-4499-b4e0-8ae6ee7a5f5c'): {'일시': '2월16일 17:05', '발파진동(cm/s)': 0.124, '진동레벨dB(V)': 64.39, '소음레벨dB(A)': 67.44}, UUID('fcea31b8-78ad-4e40-bcb5-f48af748ba99'): {'일시': '2월17일 7:00', '발파진동(cm/s)': 0.042, '진동레벨dB(V)': 55.65, '소음레벨dB(A)': 63.54}, UUID('8370a85e-fd2d-41fd-b806-a477d76a76e2'): {'일시': '2월17일 17:04', '발파진동(cm/s)': 0.187, '진동레벨dB(V)': 64.8, '소음레벨dB(A)': 62.98}, UUID('1b21d41a-0130-40cf-923a-937c6c02c900'): {'일시': '2월18일 7:00', '발파진동(cm/s)': 0.07, '진동레벨dB(V)': 56.33, '소음레벨dB(A)': 65.84}, UUID('8a5fe45a-8307-47e6-8faf-106ce684f6df'): {'일시': '2월19일 12:34', '발파진동(cm/s)': 0.092, '진동레벨dB(V)': 59.44, '소음레벨dB(A)': 66.26}, UUID('ee1d1985-b7a5-4e0a-afec-34af88e24e4c'): {'일시': '2월20일 7:00', '발파진동(cm/s)': 0.128, '진동레벨dB(V)': 67.27, '소음레벨dB(A)': 63.47}, UUID('a275ea7d-b12a-4ba7-b37f-e4a095fbef0c'): {'일시': '2월21일 7:00', '발파진동(cm/s)': nan, '진동레벨dB(V)': nan, '소음레벨dB(A)': nan}, UUID('f9ff1280-94f8-440f-b2f2-84eb547732ed'): {'일시': '2월22일 7:01', '발파진동(cm/s)': 0.233, '진동레벨dB(V)': 70.53, '소음레벨dB(A)': 62.49}}, '풍전빌딩(현장)': {UUID('3504fe1f-8c07-49d0-8ebe-8ea6cf827cc4'): {'일시': '2월1일 11:31', '발파진동(cm/s)': nan, '진동레벨dB(V)': nan, '소음레벨dB(A)': nan}, UUID('bbfe7cc1-5a34-4e05-9a55-0b48b12259cc'): {'일시': '2월2일 10:42', '발파진동(cm/s)': 0.048, '진동레벨dB(V)': 54.74, '소음레벨dB(A)': 55.37}, UUID('28b9e445-a76e-4967-a730-b5df4deed616'): {'일시': '2월3일 10:16', '발파진동(cm/s)': 0.083, '진동레벨dB(V)': 58.5, '소음레벨dB(A)': 64.24}, UUID('c0be8a02-7056-4e1d-9fef-bc04858dc47b'): {'일시': '2월4일 11:04', '발파진동(cm/s)': 0.07, '진동레벨dB(V)': 59.13, '소음레벨dB(A)': 53.8}, UUID('6465839d-1a61-4ac4-a6c2-e7ad610dd1e8'): {'일시': '2월5일 16:24', '발파진동(cm/s)': 0.081, '진동레벨dB(V)': 60.05, '소음레벨dB(A)': 54.81}, UUID('416532e2-c65a-4610-8f20-0ce86c66a53f'): {'일시': '2월6일 10:41', '발파진동(cm/s)': nan, '진동레벨dB(V)': nan, '소음레벨dB(A)': nan}, UUID('10bf7a2 ...

# %%
import pandas as pd
test = []
for item in result_dict:
    test.append([item, pd.DataFrame(result_dict[item]).transpose().reset_index(drop=True)])

print(test)
# Out:
# [['안산천주교회',              일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0     2월1일 7:01      0.123     64.92     66.36
# 1    2월1일 18:16      0.161     60.58     63.16
# 2     2월2일 7:00      0.122     68.41     69.03
# 3    2월2일 18:17      0.046     56.69     59.07
# 4     2월3일 7:01      0.059      59.6     61.86
# 5    2월3일 17:30      0.057     58.64     60.59
# 6     2월4일 7:25       0.05     57.76     61.53
# 7    2월5일 12:15        NaN       NaN       NaN
# 8     2월6일 7:00      0.062     59.16     64.92
# 9    2월6일 17:31      0.081     70.71     59.41
# 10    2월7일 7:00      0.129     65.67      65.5
# 11   2월7일 17:24      0.057     58.12     59.57
# 12  2월13일 10:12        NaN       NaN       NaN
# 13   2월14일 7:00      0.101     58.97     64.51
# 14  2월14일 18:01      0.082     59.54     64.04
# 15  2월15일 17:49      0.137     63.86     62.79
# 16   2월16일 7:00      0.208     68.43     62.08
# 17  2월16일 17:05      0.124     64.39     67.44
# 18   2월17일 7:00      0.042     55.65     63.54
# 19  2월17일 17:04      0.187      64.8     62.98
# 20   2월18일 7:00       0.07     56.33     65.84
# 21  2월19일 12:34      0.092     59.44     66.26
# 22   2월20일 7:00      0.128     67.27     63.47
# 23   2월21일 7:00        NaN       NaN       NaN
# 24   2월22일 7:01      0.233     70.53     62.49], ['풍전빌딩(현장)',              일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0    2월1일 11:31        NaN       NaN       NaN
# 1    2월2일 10:42      0.048     54.74     55.37
# 2    2월3일 10:16      0.083      58.5     64.24
# 3    2월4일 11:04       0.07     59.13      53.8
# 4    2월5일 16:24      0.081     60.05     54.81
# 5    2월6일 10:41        NaN       NaN       NaN
# 6     2월7일 9:52      0.107     62.67     56.07
# 7   2월13일 17:21      0.103     61.63     64.13
# 8    2월14일 9:55      0.093     60.41     57.29
# 9    2월15일 7:42      0.154     64.64     57.59
# 10  2월19일 16:30      0.053     56.79     54.66
# 11  2월20일 10:37        NaN       NaN       NaN
# 12  2월21일 10:40      0.231     62.25     35.52
# 13  2월22일 10:35        NaN       NaN       NaN
# 14  2월23일 10:20        NaN       NaN       NaN
# 15   2월25일 7:15      0.353     68.24     60.38], ['주공1단지아파트110동',              일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0    2월1일 11:31      0.105     64.92     60.95
# 1    2월2일 10:42      0.071     60.42     61.22
# 2    2월3일 10:16      0.092     62.41     60.64
# 3    2월4일 11:04      0.113     61.03     61.39
# 4    2월5일 16:24      0.085      61.6     63.85
# 5    2월6일 10:41        NaN       NaN       NaN
# 6     2월7일 9:52        NaN       NaN       NaN
# 7   2월13일 17:21      0.055     55.92     55.86
# 8    2월14일 9:55      0.045     58.15     58.35
# 9    2월15일 7:42      0.053     58.43     60.33
# 10  2월16일 11:21      0.091     59.52     62.23
# 11  2월17일 10:14      0.055     57.56     57.95
# 12  2월18일 10:11      0.055     56.67     60.24], ['로얄프라자',              일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0    2월1일 11:31      0.127     68.22      74.8
# 1    2월2일 10:42        NaN       NaN       NaN
# 2    2월3일 10:16        NaN       NaN       NaN
# 3    2월4일 11:04        NaN       NaN       NaN
# 4    2월5일 16:24      0.185     68.98     79.14
# 5    2월6일 10:41      0.125     66.55     72.45
# 6     2월7일 9:52      0.088     66.68     71.82
# 7   2월13일 17:21      0.096     66.37     71.92
# 8    2월14일 9:55      0.097     64.22     70.47
# 9    2월15일 7:42      0.157     70.54     72.93
# 10  2월16일 11:21      0.156     67.63     76.16
# 11  2월17일 10:14      0.101     66.23     71.74
# 12  2월18일 10:11      0.055     56.67     60.24
# 13  2월19일 16:30       0.09     65.22     70.87
# 14  2월20일 10:37      0.065     62.89     68.15
# 15  2월21일 10:40      0.046     60.47     68.46
# 16  2월22일 10:35      0.072      63.8     68.34
# 17  2월23일 10:20      0.033     57.98     64.59
# 18  2월24일 10:00      0.065     64.64     68.71
# 19   2월25일 7:15      0.115     69.63     71.83
# 20  2월26일 16:59      0.042     60.06     59.88
# 21  2월27일 12:20      0.043     59.02     62.61
# 22   2월28일 7:01      0.037     60.68     61.87
# 23  2월29일 11:51      0.098     66.04     71.27], ['주공1단지110동(현장)',             일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0  2월16일 11:21      0.232     69.72     57.03
# 1  2월17일 10:14      0.046     55.99     54.73
# 2  2월18일 10:11      0.156     66.81      58.9], ['풍전빌딩(자동화계측)',              일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0   2월19일 16:30      0.067     63.65     65.21
# 1   2월20일 10:37      0.058     63.16     62.38
# 2   2월21일 10:40      0.044      57.5     62.27
# 3   2월22일 10:35      0.069     60.53     63.09
# 4   2월23일 10:20      0.027     55.96     57.84
# 5   2월24일 10:00      0.073     60.51     64.77
# 6    2월25일 7:15        NaN       NaN       NaN
# 7   2월26일 16:59        NaN       NaN       NaN
# 8   2월27일 12:20        NaN       NaN       NaN
# 9    2월28일 7:01        NaN       NaN       NaN
# 10  2월29일 11:51      0.124     68.09     66.09], ['국원물산',              일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)
# 0   2월22일 17:35      0.042     56.89     59.88
# 1    2월23일 7:00      0.057     57.89     63.58
# 2   2월23일 16:45      0.075     56.83      65.9
# 3    2월24일 7:01      0.147     59.45     68.29
# 4   2월24일 17:37        NaN       NaN       NaN
# 5   2월25일 11:36      0.044     51.41     58.08
# 6   2월26일 12:00      0.032     49.68     61.86
# 7    2월27일 7:01      0.087     63.43     63.77
# 8   2월27일 18:30        0.1     60.78      58.5
# 9   2월28일 18:24      0.049      57.8     56.17
# 10   2월29일 7:11      0.069     62.68     62.06
# 11  2월29일 17:40      0.127     62.59     59.79]]
