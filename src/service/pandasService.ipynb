# %%
import pandas as pd
import numpy as np
import clipboard, re

title = ['발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)']

# %%
# parse process
# 1. ExtractColumns ( remove Columns in Clipboard items )
# 2. ConversionErrorValue ( Conversion Value of Error to np.NAN )
# 3. ClassficationByDate ( Classfication by Date Value )
# 4. DeleteOtherValue ( Delete Useless Value )
# 5. ExtractLocation ( Extract Location Value to List )
# 6. ListToDict ( Conversion List to Dictionary )

# %%
# 0. Copy List ( This process is implemented for test )
clipboard_list = list(filter(lambda v: v, clipboard.paste().replace("\r\n", " ").split(" ")))

print(clipboard_list)
# Out:
# ['일시', '발파횟수', '시간', '장약량(kg)', '발파위치', '발파진동및소음측정치(max값)', '지발당장약량', '총장약량', '발파패턴', 'STA', '발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)', '측정위치', '2월1일', '1회', '7:01', '0.875~2.0', '37.5', 'PD-4', '6k+854.25~857.25(종점)', '0.101', '59.60', '51.61', '삼부봉제', '2회', '9:00', '0.375~0.7', '13.5', 'PD-5', '5k+951.85~949.45(시점)', '0.040', '53.60', '55.74', '우진아트빌3차', '0.086', '58.90', '66.99', '코리안바베큐', '0.051', '58.37', '63.65', '성포중학교', '3회', '14:23', '0.875~2.0', '38.0', 'PD-4', '6k+857.25~860.25(종점)', '0.007', '44.01', '63.39', '삼부봉제', '4회', '18:10', '0.375~0.7', '13.5', 'PD-5', '5k+949.45~947.05(시점)', '0.071', '57.84', '58.95', '우창아트빌', '0.158', '61.28', '67.63', '코리안바베큐', '0.114', '63.27', '71.88', '성포중학교', '계', '102.5', '2월2일', '1회', '7:01', '0.875~2.0', '40.0', 'PD-4', '6k+860.25~863.25(종점)', '0.086', '61.32', '54.73', '삼부봉제', '2회', '8:59', '0.375~0.7', '17.0', 'PD-5', '5k+944.65~942.25(시점)', '0.049', '54.47', '55.40', '우진아트빌3차', '0.158', '69.10', '74.56', '코리안바베큐', '0.059', '59.50', '61.23', '성포중학교', '3회', '15:47', '0.875~2.0', '40.7', 'PD-4', '6k+863.25~866.25(종점)', '0.045', '56.21', '53.98', '삼부봉제', '4회', '18:09', '0.375~0.7', '16.5', 'PD-5', '5k+942.25~939.85(시점)', '0.045', '52.93', '70.09', '우창아트빌', '0.156', '67.18', '68.34', '코리안바베큐', '0.066', '62.0', '69.50', '성포중학교', '계', '114.2', '2월3일', '1회', '7:00', '0.35~0.625', '67.0', 'PD-3-1', '6k+872.25~873.5(종점)', '0.056', '60.14', '54.21', '삼부봉제', '2회', '9:01', '0.45~0.9', '73.0', 'PD-4', '5k+932.65~931.15(시점)', '0.017', '49.25', '53.64', '우진아트빌3차', '0.141', '66.73', '72.01', '코리안바베큐', '0.06', '60.59', '72.76', '성포중학교', '3회', '16:40', '0.35~0.625', '56.0', 'PD-3-1', '6k+873.5~874.75(종점)', '0.085', '64.51', '57.47', '삼부봉제', '계', '196.0', '일시', '발파횟수', '시간', '장약량(kg)', '발파위치', '발파진동및소음측정치(max값)', '지발당장약량', '총장약량', '발파패턴', 'STA', '발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)', '측정위치', '2월4일', '1회', '8:30', '0.45~0.9', '68.0', 'PD-4', '5k+931.15~929.65(시점)', '0.012', '45.74', '43.27', '우진아트빌3차', '0.04', '56.52', '64.48', '코리안바베큐', 'NT', 'NT', 'NT', '성포중학교', '2회', '16:37', '0.35~0.625', '32.2', 'PD-3-1', '6k+874.75~877.25(종점)', '0.037', '54.78', '53.2', '삼부봉제', '계', '100.2', '2월5일', '1회', '7:03', '0.35~0.625', '57.0', 'PD-3-1', '6k+877.25~878.5(종점)', '0.048', '57.71', '51.92', '삼부봉제', '2회', '11:12', '0.45~0.9', '80.0', 'PD-4', '5k+929.65~928.15(시점)', '0.023', '48.72', '49.99', '우진아트빌3차', '0.135', '63.59', '70.59', '코리안바베큐', '0.063', '56.91', '63.30', '성포중학교', '3회', '17:41', '0.35~0.625', '57.3', 'PD-3-1', '6k+878.5~879.75(종점)', '0.039', '54.83', '60.30', '삼부봉제', '계', '194.3', '2월6일', '1회', '7:02', '0.35~0.625', '67.0', 'PD-4', '5k+928.15~926.65(시점)', '0.018', '48.12', '49.04', '우창아트빌', '0.073', '63.35', '67.61', '코리안바베큐', '0.035', '55.94', '62.22', '성포중학교', '2회', '12:11', '0.45~0.90', '45.0', 'PD-3-1', '6k+879.75~881.00(종점)', '0.022', '51.79', '49.50', '삼부봉제', '3회', '18:32', '0.35~0.625', '67.0', 'PD-4', '5k+926.65~925.15(시점)', '0.082', '61.22', '56.69', '우창아트빌', '0.146', '67.43', '73.11', '코리안바베큐', '0.082', '64.70', '63.95', '성포중학교', '계', '179.0', '2월7일', '1회', '7:02', '0.45~0.9', '69.00', 'PD-3-1', '6k+882.25~883.50(종점)', '0.029', '57.36', '61.23', '삼부봉제', '2회', '9:04', '0.35~0.625', '80.50', 'PD-4', '5k+925.15~923.65(시점)', '0.031', '55.56', '57.18', '우창아트빌', '0.114', '66.68', '72.26', '코리안바베큐', '0.095', '63.23', '69.54', '성포중학교', '3회', '17:52', '0.45~0.9', '69.00', 'PD-3-1', '6k+883.50~884.75(종점)', '0.04', '60.85', '51.61', '삼부봉제', '계', '218.5', '2월8일', '1회', '7:04', '0.45~0.9', '76.00', 'PD-3-1', '6k+884.75~886.00(종점)', '0.021', '54.98', '52.62', '삼부봉제', '2회', '8:34', '0.375~0.7', '28.00', 'PD-5', '5k+938.65~936.25(시점)', '0.06', '54.02', '56.92', '우창아트빌', '0.213', '70.88', '71.42', '코리안바베큐', '0.102', '62.74', '62.17', '성포중학교', '3회', '15:06', '0.45~0.9', '76.00', 'PD-3-1', '6k+886.00~887.25(종점)', '0.036', '61.81', '54.48', '삼부봉제', '4회', '17:04', '0.375~0.7', '28.50', 'PD-5', '5k+936.25~933.85(시점)', '0.047', '54.49', '61.56', '우창아트빌', '0.141', '67.62', '70.69', '코리안바베큐', '0.106', '65.99', '60 ...

# %%
# 1. ExtractColumns
columns = []

for i in clipboard_list:
    if not re.match(r'\d+월\d+일', i):
        columns.append(i)
    else:
        break

items_list = list(filter(lambda x: x not in columns, clipboard_list))

print(columns)
print(items_list)
# Out:
# ['일시', '발파횟수', '시간', '장약량(kg)', '발파위치', '발파진동및소음측정치(max값)', '지발당장약량', '총장약량', '발파패턴', 'STA', '발파진동(cm/s)', '진동레벨dB(V)', '소음레벨dB(A)', '측정위치']
# ['2월1일', '1회', '7:01', '0.875~2.0', '37.5', 'PD-4', '6k+854.25~857.25(종점)', '0.101', '59.60', '51.61', '삼부봉제', '2회', '9:00', '0.375~0.7', '13.5', 'PD-5', '5k+951.85~949.45(시점)', '0.040', '53.60', '55.74', '우진아트빌3차', '0.086', '58.90', '66.99', '코리안바베큐', '0.051', '58.37', '63.65', '성포중학교', '3회', '14:23', '0.875~2.0', '38.0', 'PD-4', '6k+857.25~860.25(종점)', '0.007', '44.01', '63.39', '삼부봉제', '4회', '18:10', '0.375~0.7', '13.5', 'PD-5', '5k+949.45~947.05(시점)', '0.071', '57.84', '58.95', '우창아트빌', '0.158', '61.28', '67.63', '코리안바베큐', '0.114', '63.27', '71.88', '성포중학교', '계', '102.5', '2월2일', '1회', '7:01', '0.875~2.0', '40.0', 'PD-4', '6k+860.25~863.25(종점)', '0.086', '61.32', '54.73', '삼부봉제', '2회', '8:59', '0.375~0.7', '17.0', 'PD-5', '5k+944.65~942.25(시점)', '0.049', '54.47', '55.40', '우진아트빌3차', '0.158', '69.10', '74.56', '코리안바베큐', '0.059', '59.50', '61.23', '성포중학교', '3회', '15:47', '0.875~2.0', '40.7', 'PD-4', '6k+863.25~866.25(종점)', '0.045', '56.21', '53.98', '삼부봉제', '4회', '18:09', '0.375~0.7', '16.5', 'PD-5', '5k+942.25~939.85(시점)', '0.045', '52.93', '70.09', '우창아트빌', '0.156', '67.18', '68.34', '코리안바베큐', '0.066', '62.0', '69.50', '성포중학교', '계', '114.2', '2월3일', '1회', '7:00', '0.35~0.625', '67.0', 'PD-3-1', '6k+872.25~873.5(종점)', '0.056', '60.14', '54.21', '삼부봉제', '2회', '9:01', '0.45~0.9', '73.0', 'PD-4', '5k+932.65~931.15(시점)', '0.017', '49.25', '53.64', '우진아트빌3차', '0.141', '66.73', '72.01', '코리안바베큐', '0.06', '60.59', '72.76', '성포중학교', '3회', '16:40', '0.35~0.625', '56.0', 'PD-3-1', '6k+873.5~874.75(종점)', '0.085', '64.51', '57.47', '삼부봉제', '계', '196.0', '2월4일', '1회', '8:30', '0.45~0.9', '68.0', 'PD-4', '5k+931.15~929.65(시점)', '0.012', '45.74', '43.27', '우진아트빌3차', '0.04', '56.52', '64.48', '코리안바베큐', 'NT', 'NT', 'NT', '성포중학교', '2회', '16:37', '0.35~0.625', '32.2', 'PD-3-1', '6k+874.75~877.25(종점)', '0.037', '54.78', '53.2', '삼부봉제', '계', '100.2', '2월5일', '1회', '7:03', '0.35~0.625', '57.0', 'PD-3-1', '6k+877.25~878.5(종점)', '0.048', '57.71', '51.92', '삼부봉제', '2회', '11:12', '0.45~0.9', '80.0', 'PD-4', '5k+929.65~928.15(시점)', '0.023', '48.72', '49.99', '우진아트빌3차', '0.135', '63.59', '70.59', '코리안바베큐', '0.063', '56.91', '63.30', '성포중학교', '3회', '17:41', '0.35~0.625', '57.3', 'PD-3-1', '6k+878.5~879.75(종점)', '0.039', '54.83', '60.30', '삼부봉제', '계', '194.3', '2월6일', '1회', '7:02', '0.35~0.625', '67.0', 'PD-4', '5k+928.15~926.65(시점)', '0.018', '48.12', '49.04', '우창아트빌', '0.073', '63.35', '67.61', '코리안바베큐', '0.035', '55.94', '62.22', '성포중학교', '2회', '12:11', '0.45~0.90', '45.0', 'PD-3-1', '6k+879.75~881.00(종점)', '0.022', '51.79', '49.50', '삼부봉제', '3회', '18:32', '0.35~0.625', '67.0', 'PD-4', '5k+926.65~925.15(시점)', '0.082', '61.22', '56.69', '우창아트빌', '0.146', '67.43', '73.11', '코리안바베큐', '0.082', '64.70', '63.95', '성포중학교', '계', '179.0', '2월7일', '1회', '7:02', '0.45~0.9', '69.00', 'PD-3-1', '6k+882.25~883.50(종점)', '0.029', '57.36', '61.23', '삼부봉제', '2회', '9:04', '0.35~0.625', '80.50', 'PD-4', '5k+925.15~923.65(시점)', '0.031', '55.56', '57.18', '우창아트빌', '0.114', '66.68', '72.26', '코리안바베큐', '0.095', '63.23', '69.54', '성포중학교', '3회', '17:52', '0.45~0.9', '69.00', 'PD-3-1', '6k+883.50~884.75(종점)', '0.04', '60.85', '51.61', '삼부봉제', '계', '218.5', '2월8일', '1회', '7:04', '0.45~0.9', '76.00', 'PD-3-1', '6k+884.75~886.00(종점)', '0.021', '54.98', '52.62', '삼부봉제', '2회', '8:34', '0.375~0.7', '28.00', 'PD-5', '5k+938.65~936.25(시점)', '0.06', '54.02', '56.92', '우창아트빌', '0.213', '70.88', '71.42', '코리안바베큐', '0.102', '62.74', '62.17', '성포중학교', '3회', '15:06', '0.45~0.9', '76.00', 'PD-3-1', '6k+886.00~887.25(종점)', '0.036', '61.81', '54.48', '삼부봉제', '4회', '17:04', '0.375~0.7', '28.50', 'PD-5', '5k+936.25~933.85(시점)', '0.047', '54.49', '61.56', '우창아트빌', '0.141', '67.62', '70.69', '코리안바베큐', '0.106', '65.99', '60.05', '성포중학교', '계', '208.5', '2월9일', '1회', '7:02', '0.45~0.9', '58.0', 'PD-3-1', '6k+887.25~888.5(종점)', '0.031', '58.73', '53.24', '삼부봉제', '2회', '9:04', '0.375~0.7', '52.0', 'PD-4', '5k+932.65~931.15(시점)', '0.037', '52.35', '56.71', '우창아트빌', '0.156', '66.80', '71.27', '코리안바베큐', ' ...

# %%
# 2. ConversionErrorValue
for x, i in enumerate(items_list):
    if i == "계측기오류":
        for j in range(0, 3):
            if j < 1:
                items_list.pop(x + j)
            items_list.insert(x + j, "계측기 오류")

print(items_list)
# Out:
# ['2월1일', '1회', '7:01', '0.875~2.0', '37.5', 'PD-4', '6k+854.25~857.25(종점)', '0.101', '59.60', '51.61', '삼부봉제', '2회', '9:00', '0.375~0.7', '13.5', 'PD-5', '5k+951.85~949.45(시점)', '0.040', '53.60', '55.74', '우진아트빌3차', '0.086', '58.90', '66.99', '코리안바베큐', '0.051', '58.37', '63.65', '성포중학교', '3회', '14:23', '0.875~2.0', '38.0', 'PD-4', '6k+857.25~860.25(종점)', '0.007', '44.01', '63.39', '삼부봉제', '4회', '18:10', '0.375~0.7', '13.5', 'PD-5', '5k+949.45~947.05(시점)', '0.071', '57.84', '58.95', '우창아트빌', '0.158', '61.28', '67.63', '코리안바베큐', '0.114', '63.27', '71.88', '성포중학교', '계', '102.5', '2월2일', '1회', '7:01', '0.875~2.0', '40.0', 'PD-4', '6k+860.25~863.25(종점)', '0.086', '61.32', '54.73', '삼부봉제', '2회', '8:59', '0.375~0.7', '17.0', 'PD-5', '5k+944.65~942.25(시점)', '0.049', '54.47', '55.40', '우진아트빌3차', '0.158', '69.10', '74.56', '코리안바베큐', '0.059', '59.50', '61.23', '성포중학교', '3회', '15:47', '0.875~2.0', '40.7', 'PD-4', '6k+863.25~866.25(종점)', '0.045', '56.21', '53.98', '삼부봉제', '4회', '18:09', '0.375~0.7', '16.5', 'PD-5', '5k+942.25~939.85(시점)', '0.045', '52.93', '70.09', '우창아트빌', '0.156', '67.18', '68.34', '코리안바베큐', '0.066', '62.0', '69.50', '성포중학교', '계', '114.2', '2월3일', '1회', '7:00', '0.35~0.625', '67.0', 'PD-3-1', '6k+872.25~873.5(종점)', '0.056', '60.14', '54.21', '삼부봉제', '2회', '9:01', '0.45~0.9', '73.0', 'PD-4', '5k+932.65~931.15(시점)', '0.017', '49.25', '53.64', '우진아트빌3차', '0.141', '66.73', '72.01', '코리안바베큐', '0.06', '60.59', '72.76', '성포중학교', '3회', '16:40', '0.35~0.625', '56.0', 'PD-3-1', '6k+873.5~874.75(종점)', '0.085', '64.51', '57.47', '삼부봉제', '계', '196.0', '2월4일', '1회', '8:30', '0.45~0.9', '68.0', 'PD-4', '5k+931.15~929.65(시점)', '0.012', '45.74', '43.27', '우진아트빌3차', '0.04', '56.52', '64.48', '코리안바베큐', 'NT', 'NT', 'NT', '성포중학교', '2회', '16:37', '0.35~0.625', '32.2', 'PD-3-1', '6k+874.75~877.25(종점)', '0.037', '54.78', '53.2', '삼부봉제', '계', '100.2', '2월5일', '1회', '7:03', '0.35~0.625', '57.0', 'PD-3-1', '6k+877.25~878.5(종점)', '0.048', '57.71', '51.92', '삼부봉제', '2회', '11:12', '0.45~0.9', '80.0', 'PD-4', '5k+929.65~928.15(시점)', '0.023', '48.72', '49.99', '우진아트빌3차', '0.135', '63.59', '70.59', '코리안바베큐', '0.063', '56.91', '63.30', '성포중학교', '3회', '17:41', '0.35~0.625', '57.3', 'PD-3-1', '6k+878.5~879.75(종점)', '0.039', '54.83', '60.30', '삼부봉제', '계', '194.3', '2월6일', '1회', '7:02', '0.35~0.625', '67.0', 'PD-4', '5k+928.15~926.65(시점)', '0.018', '48.12', '49.04', '우창아트빌', '0.073', '63.35', '67.61', '코리안바베큐', '0.035', '55.94', '62.22', '성포중학교', '2회', '12:11', '0.45~0.90', '45.0', 'PD-3-1', '6k+879.75~881.00(종점)', '0.022', '51.79', '49.50', '삼부봉제', '3회', '18:32', '0.35~0.625', '67.0', 'PD-4', '5k+926.65~925.15(시점)', '0.082', '61.22', '56.69', '우창아트빌', '0.146', '67.43', '73.11', '코리안바베큐', '0.082', '64.70', '63.95', '성포중학교', '계', '179.0', '2월7일', '1회', '7:02', '0.45~0.9', '69.00', 'PD-3-1', '6k+882.25~883.50(종점)', '0.029', '57.36', '61.23', '삼부봉제', '2회', '9:04', '0.35~0.625', '80.50', 'PD-4', '5k+925.15~923.65(시점)', '0.031', '55.56', '57.18', '우창아트빌', '0.114', '66.68', '72.26', '코리안바베큐', '0.095', '63.23', '69.54', '성포중학교', '3회', '17:52', '0.45~0.9', '69.00', 'PD-3-1', '6k+883.50~884.75(종점)', '0.04', '60.85', '51.61', '삼부봉제', '계', '218.5', '2월8일', '1회', '7:04', '0.45~0.9', '76.00', 'PD-3-1', '6k+884.75~886.00(종점)', '0.021', '54.98', '52.62', '삼부봉제', '2회', '8:34', '0.375~0.7', '28.00', 'PD-5', '5k+938.65~936.25(시점)', '0.06', '54.02', '56.92', '우창아트빌', '0.213', '70.88', '71.42', '코리안바베큐', '0.102', '62.74', '62.17', '성포중학교', '3회', '15:06', '0.45~0.9', '76.00', 'PD-3-1', '6k+886.00~887.25(종점)', '0.036', '61.81', '54.48', '삼부봉제', '4회', '17:04', '0.375~0.7', '28.50', 'PD-5', '5k+936.25~933.85(시점)', '0.047', '54.49', '61.56', '우창아트빌', '0.141', '67.62', '70.69', '코리안바베큐', '0.106', '65.99', '60.05', '성포중학교', '계', '208.5', '2월9일', '1회', '7:02', '0.45~0.9', '58.0', 'PD-3-1', '6k+887.25~888.5(종점)', '0.031', '58.73', '53.24', '삼부봉제', '2회', '9:04', '0.375~0.7', '52.0', 'PD-4', '5k+932.65~931.15(시점)', '0.037', '52.35', '56.71', '우창아트빌', '0.156', '66.80', '71.27', '코리안바베큐', ' ...

# %%
# 3. ClassficationByDate
section = []
current_section = []

for i in items_list:
    if re.match(r'\d+월\d+일', i):
        if current_section:
            section.append(current_section)
            current_section = []
    current_section.append(i)

if current_section:
    section.append(current_section)

print(section)
# Out:
# [['2월1일', '1회', '7:01', '0.875~2.0', '37.5', 'PD-4', '6k+854.25~857.25(종점)', '0.101', '59.60', '51.61', '삼부봉제', '2회', '9:00', '0.375~0.7', '13.5', 'PD-5', '5k+951.85~949.45(시점)', '0.040', '53.60', '55.74', '우진아트빌3차', '0.086', '58.90', '66.99', '코리안바베큐', '0.051', '58.37', '63.65', '성포중학교', '3회', '14:23', '0.875~2.0', '38.0', 'PD-4', '6k+857.25~860.25(종점)', '0.007', '44.01', '63.39', '삼부봉제', '4회', '18:10', '0.375~0.7', '13.5', 'PD-5', '5k+949.45~947.05(시점)', '0.071', '57.84', '58.95', '우창아트빌', '0.158', '61.28', '67.63', '코리안바베큐', '0.114', '63.27', '71.88', '성포중학교', '계', '102.5'], ['2월2일', '1회', '7:01', '0.875~2.0', '40.0', 'PD-4', '6k+860.25~863.25(종점)', '0.086', '61.32', '54.73', '삼부봉제', '2회', '8:59', '0.375~0.7', '17.0', 'PD-5', '5k+944.65~942.25(시점)', '0.049', '54.47', '55.40', '우진아트빌3차', '0.158', '69.10', '74.56', '코리안바베큐', '0.059', '59.50', '61.23', '성포중학교', '3회', '15:47', '0.875~2.0', '40.7', 'PD-4', '6k+863.25~866.25(종점)', '0.045', '56.21', '53.98', '삼부봉제', '4회', '18:09', '0.375~0.7', '16.5', 'PD-5', '5k+942.25~939.85(시점)', '0.045', '52.93', '70.09', '우창아트빌', '0.156', '67.18', '68.34', '코리안바베큐', '0.066', '62.0', '69.50', '성포중학교', '계', '114.2'], ['2월3일', '1회', '7:00', '0.35~0.625', '67.0', 'PD-3-1', '6k+872.25~873.5(종점)', '0.056', '60.14', '54.21', '삼부봉제', '2회', '9:01', '0.45~0.9', '73.0', 'PD-4', '5k+932.65~931.15(시점)', '0.017', '49.25', '53.64', '우진아트빌3차', '0.141', '66.73', '72.01', '코리안바베큐', '0.06', '60.59', '72.76', '성포중학교', '3회', '16:40', '0.35~0.625', '56.0', 'PD-3-1', '6k+873.5~874.75(종점)', '0.085', '64.51', '57.47', '삼부봉제', '계', '196.0'], ['2월4일', '1회', '8:30', '0.45~0.9', '68.0', 'PD-4', '5k+931.15~929.65(시점)', '0.012', '45.74', '43.27', '우진아트빌3차', '0.04', '56.52', '64.48', '코리안바베큐', 'NT', 'NT', 'NT', '성포중학교', '2회', '16:37', '0.35~0.625', '32.2', 'PD-3-1', '6k+874.75~877.25(종점)', '0.037', '54.78', '53.2', '삼부봉제', '계', '100.2'], ['2월5일', '1회', '7:03', '0.35~0.625', '57.0', 'PD-3-1', '6k+877.25~878.5(종점)', '0.048', '57.71', '51.92', '삼부봉제', '2회', '11:12', '0.45~0.9', '80.0', 'PD-4', '5k+929.65~928.15(시점)', '0.023', '48.72', '49.99', '우진아트빌3차', '0.135', '63.59', '70.59', '코리안바베큐', '0.063', '56.91', '63.30', '성포중학교', '3회', '17:41', '0.35~0.625', '57.3', 'PD-3-1', '6k+878.5~879.75(종점)', '0.039', '54.83', '60.30', '삼부봉제', '계', '194.3'], ['2월6일', '1회', '7:02', '0.35~0.625', '67.0', 'PD-4', '5k+928.15~926.65(시점)', '0.018', '48.12', '49.04', '우창아트빌', '0.073', '63.35', '67.61', '코리안바베큐', '0.035', '55.94', '62.22', '성포중학교', '2회', '12:11', '0.45~0.90', '45.0', 'PD-3-1', '6k+879.75~881.00(종점)', '0.022', '51.79', '49.50', '삼부봉제', '3회', '18:32', '0.35~0.625', '67.0', 'PD-4', '5k+926.65~925.15(시점)', '0.082', '61.22', '56.69', '우창아트빌', '0.146', '67.43', '73.11', '코리안바베큐', '0.082', '64.70', '63.95', '성포중학교', '계', '179.0'], ['2월7일', '1회', '7:02', '0.45~0.9', '69.00', 'PD-3-1', '6k+882.25~883.50(종점)', '0.029', '57.36', '61.23', '삼부봉제', '2회', '9:04', '0.35~0.625', '80.50', 'PD-4', '5k+925.15~923.65(시점)', '0.031', '55.56', '57.18', '우창아트빌', '0.114', '66.68', '72.26', '코리안바베큐', '0.095', '63.23', '69.54', '성포중학교', '3회', '17:52', '0.45~0.9', '69.00', 'PD-3-1', '6k+883.50~884.75(종점)', '0.04', '60.85', '51.61', '삼부봉제', '계', '218.5'], ['2월8일', '1회', '7:04', '0.45~0.9', '76.00', 'PD-3-1', '6k+884.75~886.00(종점)', '0.021', '54.98', '52.62', '삼부봉제', '2회', '8:34', '0.375~0.7', '28.00', 'PD-5', '5k+938.65~936.25(시점)', '0.06', '54.02', '56.92', '우창아트빌', '0.213', '70.88', '71.42', '코리안바베큐', '0.102', '62.74', '62.17', '성포중학교', '3회', '15:06', '0.45~0.9', '76.00', 'PD-3-1', '6k+886.00~887.25(종점)', '0.036', '61.81', '54.48', '삼부봉제', '4회', '17:04', '0.375~0.7', '28.50', 'PD-5', '5k+936.25~933.85(시점)', '0.047', '54.49', '61.56', '우창아트빌', '0.141', '67.62', '70.69', '코리안바베큐', '0.106', '65.99', '60.05', '성포중학교', '계', '208.5'], ['2월9일', '1회', '7:02', '0.45~0.9', '58.0', 'PD-3-1', '6k+887.25~888.5(종점)', '0.031', '58.73', '53.24', '삼부봉제', '2회', '9:04', '0.375~0.7', '52.0', 'PD-4', '5k+932.65~931.15(시점)', '0.037', '52.35', '56.71', '우창아트빌', '0.156', '66.80', '71 ...

# %%
# 4. DelOtherValue
section2 = []

for j in section:
    temp_list = []
    first_key = None
    for x, i in enumerate(j):
        if first_key is None and re.match(r'\d.*?\.\d+[~-]\d+\.\d+', i):
            first_key = i
        elif first_key is not None and re.match(r'\d.*?\.\d+[~-]\d+\.\d+', i):
            first_key = None
        elif first_key is None and i != '계' and j[x - 1] != '계':
            temp_list.append(i)
    section2.append(temp_list)

print(section2)
# Out:
# [['2월1일', '1회', '7:01', '0.101', '59.60', '51.61', '삼부봉제', '2회', '9:00', '0.040', '53.60', '55.74', '우진아트빌3차', '0.086', '58.90', '66.99', '코리안바베큐', '0.051', '58.37', '63.65', '성포중학교', '3회', '14:23', '0.007', '44.01', '63.39', '삼부봉제', '4회', '18:10', '0.071', '57.84', '58.95', '우창아트빌', '0.158', '61.28', '67.63', '코리안바베큐', '0.114', '63.27', '71.88', '성포중학교'], ['2월2일', '1회', '7:01', '0.086', '61.32', '54.73', '삼부봉제', '2회', '8:59', '0.049', '54.47', '55.40', '우진아트빌3차', '0.158', '69.10', '74.56', '코리안바베큐', '0.059', '59.50', '61.23', '성포중학교', '3회', '15:47', '0.045', '56.21', '53.98', '삼부봉제', '4회', '18:09', '0.045', '52.93', '70.09', '우창아트빌', '0.156', '67.18', '68.34', '코리안바베큐', '0.066', '62.0', '69.50', '성포중학교'], ['2월3일', '1회', '7:00', '0.056', '60.14', '54.21', '삼부봉제', '2회', '9:01', '0.017', '49.25', '53.64', '우진아트빌3차', '0.141', '66.73', '72.01', '코리안바베큐', '0.06', '60.59', '72.76', '성포중학교', '3회', '16:40', '0.085', '64.51', '57.47', '삼부봉제'], ['2월4일', '1회', '8:30', '0.012', '45.74', '43.27', '우진아트빌3차', '0.04', '56.52', '64.48', '코리안바베큐', 'NT', 'NT', 'NT', '성포중학교', '2회', '16:37', '0.037', '54.78', '53.2', '삼부봉제'], ['2월5일', '1회', '7:03', '0.048', '57.71', '51.92', '삼부봉제', '2회', '11:12', '0.023', '48.72', '49.99', '우진아트빌3차', '0.135', '63.59', '70.59', '코리안바베큐', '0.063', '56.91', '63.30', '성포중학교', '3회', '17:41', '0.039', '54.83', '60.30', '삼부봉제'], ['2월6일', '1회', '7:02', '0.018', '48.12', '49.04', '우창아트빌', '0.073', '63.35', '67.61', '코리안바베큐', '0.035', '55.94', '62.22', '성포중학교', '2회', '12:11', '0.022', '51.79', '49.50', '삼부봉제', '3회', '18:32', '0.082', '61.22', '56.69', '우창아트빌', '0.146', '67.43', '73.11', '코리안바베큐', '0.082', '64.70', '63.95', '성포중학교'], ['2월7일', '1회', '7:02', '0.029', '57.36', '61.23', '삼부봉제', '2회', '9:04', '0.031', '55.56', '57.18', '우창아트빌', '0.114', '66.68', '72.26', '코리안바베큐', '0.095', '63.23', '69.54', '성포중학교', '3회', '17:52', '0.04', '60.85', '51.61', '삼부봉제'], ['2월8일', '1회', '7:04', '0.021', '54.98', '52.62', '삼부봉제', '2회', '8:34', '0.06', '54.02', '56.92', '우창아트빌', '0.213', '70.88', '71.42', '코리안바베큐', '0.102', '62.74', '62.17', '성포중학교', '3회', '15:06', '0.036', '61.81', '54.48', '삼부봉제', '4회', '17:04', '0.047', '54.49', '61.56', '우창아트빌', '0.141', '67.62', '70.69', '코리안바베큐', '0.106', '65.99', '60.05', '성포중학교'], ['2월9일', '1회', '7:02', '0.031', '58.73', '53.24', '삼부봉제', '2회', '9:04', '0.037', '52.35', '56.71', '우창아트빌', '0.156', '66.80', '71.27', '코리안바베큐', '계측기 오류', '계측기 오류', '계측기 오류', '성포중학교', '3회', '18:01', '0.093', '58.63', '57.86', '우창아트빌', '4회', '18:01', '0.006', '44.67', '50.33', '우창아트빌', '0.139', '66.19', '67.79', '코리안바베큐', '0.144', '64.79', '66.82', '성포중학교'], ['2월10일', '1회', '7:02', '0.034', '52.37', '55.14', '우창아트빌', '0.115', '64.94', '67.94', '코리안바베큐', '0.17', '66.90', '62.26', '성포중학교', '2회', '9:34', '0.058', '63.49', '56.23', '삼부봉제', '3회', '17:42', '0.032', '52.28', '57.97', '우창아트빌', '0.137', '66.11', '66.80', '코리안바베큐', '0.139', '64.91', '62.36', '성포중학교'], ['2월11일', '1회', '7:02', '0.071', '60.46', '54.67', '삼부봉제', '2회', '9:50', '0.092', '61.78', '60.18', '태영빌', '0.152', '68.25', '68.25', '코리안바베큐', '0.102', '65.63', '70.10', '성포중학교', '3회', '18:40', '0.152', '64.66', '59.68', '삼부봉제'], ['2월12일', '1회', '7:02', '0.117', '65.55', '63.49', '삼부봉제', '2회', '9:52', '0.04', '58.10', '59.67', '태영빌', '0.167', '70.68', '71.18', '코리안바베큐', '0.152', '69.56', '63.58', '성포중학교', '3회', '18:42', '0.153', '64.83', '60.35', '삼부봉제'], ['2월13일', '1회', '7:04', '계측기 오류', '계측기 오류', '계측기 오류', '태영빌', '0.207', '73.2', '73.37', '코리안바베큐', '0.206', '71.96', '65.78', '성포중학교', '2회', '10:45', '0.094', '67.38', '59.67', '삼부봉제', '3회', '17:12', '0.027', '53.66', '57.05', '태영빌', '0.104', '65.94', '67.33', '코리안바베큐', '0.123', '67.55', '61.29', '성포중학교'], ['2월14일', '1회', '8:32', '0.034', '52.93', '57.26', '태영빌', '0.144', '67.08', '69.57', '코리안바베큐', '0.115', '64.47', '60.44', '성포중학교', '2회', '14:27', '0.092', '69.86', '58.72', '삼부봉제', '3회', '18:18', '0.088', '61.98', '60.68', '태영빌', '0.105', '67.10', '67.57', '코리안바베큐', '0.111', '65.72', '58.58', '성포중학교'], ['2월15일', '1 ...

# %%
# 5. ExtractLocation
location = []
date_count, count_count, time_count = None, None, None
pass_count = 0

for i in section2:
    for j in i:
        # if j.replace("(", "").replace(")", "").isalnum() and not j.isdigit() and not re.match(r'\d+월\d+일', j) and not re.match(r'\d+회', j):
        if re.match(r'\d+월\d+일', j):
            date_count = True
            print(f'date_count : {j}')
        elif re.match(r'\d+회', j):
            count_count = True
            print(f'count_count : {j}')
        elif re.match(r'\d+:\d+', j):
            time_count = True
            print(f'time_count : {j}')
        elif date_count and count_count and time_count and pass_count == 3:
            location.append(j)
            pass_count = 0
        elif date_count and count_count and time_count:
            pass_count += 1
            print(f'pass_count : {j}')


location = list(set(location))

location
# Out:
# date_count : 2월1일
# count_count : 1회
# time_count : 7:01
# pass_count : 0.101
# pass_count : 59.60
# pass_count : 51.61
# count_count : 2회
# time_count : 9:00
# pass_count : 0.040
# pass_count : 53.60
# pass_count : 55.74
# pass_count : 0.086
# pass_count : 58.90
# pass_count : 66.99
# pass_count : 0.051
# pass_count : 58.37
# pass_count : 63.65
# count_count : 3회
# time_count : 14:23
# pass_count : 0.007
# pass_count : 44.01
# pass_count : 63.39
# count_count : 4회
# time_count : 18:10
# pass_count : 0.071
# pass_count : 57.84
# pass_count : 58.95
# pass_count : 0.158
# pass_count : 61.28
# pass_count : 67.63
# pass_count : 0.114
# pass_count : 63.27
# pass_count : 71.88
# date_count : 2월2일
# count_count : 1회
# time_count : 7:01
# pass_count : 0.086
# pass_count : 61.32
# pass_count : 54.73
# count_count : 2회
# time_count : 8:59
# pass_count : 0.049
# pass_count : 54.47
# pass_count : 55.40
# pass_count : 0.158
# pass_count : 69.10
# pass_count : 74.56
# pass_count : 0.059
# pass_count : 59.50
# pass_count : 61.23
# count_count : 3회
# time_count : 15:47
# pass_count : 0.045
# pass_count : 56.21
# pass_count : 53.98
# count_count : 4회
# time_count : 18:09
# pass_count : 0.045
# pass_count : 52.93
# pass_count : 70.09
# pass_count : 0.156
# pass_count : 67.18
# pass_count : 68.34
# pass_count : 0.066
# pass_count : 62.0
# pass_count : 69.50
# date_count : 2월3일
# count_count : 1회
# time_count : 7:00
# pass_count : 0.056
# pass_count : 60.14
# pass_count : 54.21
# count_count : 2회
# time_count : 9:01
# pass_count : 0.017
# pass_count : 49.25
# pass_count : 53.64
# pass_count : 0.141
# pass_count : 66.73
# pass_count : 72.01
# pass_count : 0.06
# pass_count : 60.59
# pass_count : 72.76
# count_count : 3회
# time_count : 16:40
# pass_count : 0.085
# pass_count : 64.51
# pass_count : 57.47
# date_count : 2월4일
# count_count : 1회
# time_count : 8:30
# pass_count : 0.012
# pass_count : 45.74
# pass_count : 43.27
# pass_count : 0.04
# pass_count : 56.52
# pass_count : 64.48
# pass_count : NT
# pass_count : NT
# pass_count : NT
# count_count : 2회
# time_count : 16:37
# pass_count : 0.037
# pass_count : 54.78
# pass_count : 53.2
# date_count : 2월5일
# count_count : 1회
# time_count : 7:03
# pass_count : 0.048
# pass_count : 57.71
# pass_count : 51.92
# count_count : 2회
# time_count : 11:12
# pass_count : 0.023
# pass_count : 48.72
# pass_count : 49.99
# pass_count : 0.135
# pass_count : 63.59
# pass_count : 70.59
# pass_count : 0.063
# pass_count : 56.91
# pass_count : 63.30
# count_count : 3회
# time_count : 17:41
# pass_count : 0.039
# pass_count : 54.83
# pass_count : 60.30
# date_count : 2월6일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.018
# pass_count : 48.12
# pass_count : 49.04
# pass_count : 0.073
# pass_count : 63.35
# pass_count : 67.61
# pass_count : 0.035
# pass_count : 55.94
# pass_count : 62.22
# count_count : 2회
# time_count : 12:11
# pass_count : 0.022
# pass_count : 51.79
# pass_count : 49.50
# count_count : 3회
# time_count : 18:32
# pass_count : 0.082
# pass_count : 61.22
# pass_count : 56.69
# pass_count : 0.146
# pass_count : 67.43
# pass_count : 73.11
# pass_count : 0.082
# pass_count : 64.70
# pass_count : 63.95
# date_count : 2월7일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.029
# pass_count : 57.36
# pass_count : 61.23
# count_count : 2회
# time_count : 9:04
# pass_count : 0.031
# pass_count : 55.56
# pass_count : 57.18
# pass_count : 0.114
# pass_count : 66.68
# pass_count : 72.26
# pass_count : 0.095
# pass_count : 63.23
# pass_count : 69.54
# count_count : 3회
# time_count : 17:52
# pass_count : 0.04
# pass_count : 60.85
# pass_count : 51.61
# date_count : 2월8일
# count_count : 1회
# time_count : 7:04
# pass_count : 0.021
# pass_count : 54.98
# pass_count : 52.62
# count_count : 2회
# time_count : 8:34
# pass_count : 0.06
# pass_count : 54.02
# pass_count : 56.92
# pass_count : 0.213
# pass_count : 70.88
# pass_count : 71.42
# pass_count : 0.102
# pass_count : 62.74
# pass_count : 62.17
# count_count : 3회
# time_count : 15:06
# pass_count : 0.036
# pass_count : 61.81
# pass_count : 54.48
# count_count : 4회
# time_count : 17:04
# pass_count : 0.047
# pass_count : 54.49
# pass_count : 61.56
# pass_count : 0.141
# pass_count : 67.62
# pass_count : 70.69
# pass_count : 0.106
# pass_count : 65.99
# pass_count : 60.05
# date_count : 2월9일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.031
# pass_count : 58.73
# pass_count : 53.24
# count_count : 2회
# time_count : 9:04
# pass_count : 0.037
# pass_count : 52.35
# pass_count : 56.71
# pass_count : 0.156
# pass_count : 66.80
# pass_count : 71.27
# pass_count : 계측기 오류
# pass_count : 계측기 오류
# pass_count : 계측기 오류
# count_count : 3회
# time_count : 18:01
# pass_count : 0.093
# pass_count : 58.63
# pass_count : 57.86
# count_count : 4회
# time_count : 18:01
# pass_count : 0.006
# pass_count : 44.67
# pass_count : 50.33
# pass_count : 0.139
# pass_count : 66.19
# pass_count : 67.79
# pass_count : 0.144
# pass_count : 64.79
# pass_count : 66.82
# date_count : 2월10일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.034
# pass_count : 52.37
# pass_count : 55.14
# pass_count : 0.115
# pass_count : 64.94
# pass_count : 67.94
# pass_count : 0.17
# pass_count : 66.90
# pass_count : 62.26
# count_count : 2회
# time_count : 9:34
# pass_count : 0.058
# pass_count : 63.49
# pass_count : 56.23
# count_count : 3회
# time_count : 17:42
# pass_count : 0.032
# pass_count : 52.28
# pass_count : 57.97
# pass_count : 0.137
# pass_count : 66.11
# pass_count : 66.80
# pass_count : 0.139
# pass_count : 64.91
# pass_count : 62.36
# date_count : 2월11일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.071
# pass_count : 60.46
# pass_count : 54.67
# count_count : 2회
# time_count : 9:50
# pass_count : 0.092
# pass_count : 61.78
# pass_count : 60.18
# pass_count : 0.152
# pass_count : 68.25
# pass_count : 68.25
# pass_count : 0.102
# pass_count : 65.63
# pass_count : 70.10
# count_count : 3회
# time_count : 18:40
# pass_count : 0.152
# pass_count : 64.66
# pass_count : 59.68
# date_count : 2월12일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.117
# pass_count : 65.55
# pass_count : 63.49
# count_count : 2회
# time_count : 9:52
# pass_count : 0.04
# pass_count : 58.10
# pass_count : 59.67
# pass_count : 0.167
# pass_count : 70.68
# pass_count : 71.18
# pass_count : 0.152
# pass_count : 69.56
# pass_count : 63.58
# count_count : 3회
# time_count : 18:42
# pass_count : 0.153
# pass_count : 64.83
# pass_count : 60.35
# date_count : 2월13일
# count_count : 1회
# time_count : 7:04
# pass_count : 계측기 오류
# pass_count : 계측기 오류
# pass_count : 계측기 오류
# pass_count : 0.207
# pass_count : 73.2
# pass_count : 73.37
# pass_count : 0.206
# pass_count : 71.96
# pass_count : 65.78
# count_count : 2회
# time_count : 10:45
# pass_count : 0.094
# pass_count : 67.38
# pass_count : 59.67
# count_count : 3회
# time_count : 17:12
# pass_count : 0.027
# pass_count : 53.66
# pass_count : 57.05
# pass_count : 0.104
# pass_count : 65.94
# pass_count : 67.33
# pass_count : 0.123
# pass_count : 67.55
# pass_count : 61.29
# date_count : 2월14일
# count_count : 1회
# time_count : 8:32
# pass_count : 0.034
# pass_count : 52.93
# pass_count : 57.26
# pass_count : 0.144
# pass_count : 67.08
# pass_count : 69.57
# pass_count : 0.115
# pass_count : 64.47
# pass_count : 60.44
# count_count : 2회
# time_count : 14:27
# pass_count : 0.092
# pass_count : 69.86
# pass_count : 58.72
# count_count : 3회
# time_count : 18:18
# pass_count : 0.088
# pass_count : 61.98
# pass_count : 60.68
# pass_count : 0.105
# pass_count : 67.10
# pass_count : 67.57
# pass_count : 0.111
# pass_count : 65.72
# pass_count : 58.58
# date_count : 2월15일
# count_count : 1회
# time_count : 7:03
# pass_count : 0.153
# pass_count : 65.84
# pass_count : 60.94
# count_count : 2회
# time_count : 10:14
# pass_count : 0.062
# pass_count : 57.64
# pass_count : 60.18
# pass_count : 0.149
# pass_count : 68.15
# pass_count : 69.49
# pass_count : 0.135
# pass_count : 68.46
# pass_count : 74.55
# count_count : 3회
# time_count : 18:29
# pass_count : 0.124
# pass_count : 65.04
# pass_count : 60.35
# date_count : 2월16일
# count_count : 1회
# time_count : 8:32
# pass_count : 0.169
# pass_count : 64.83
# pass_count : 67.94
# pass_count : 0.118
# pass_count : 66.01
# pass_count : 67.26
# pass_count : 0.146
# pass_count : 66.68
# pass_count : 60.5
# count_count : 2회
# time_count : 12:02
# pass_count : 0.194
# pass_count : 66.65
# pass_count : 61.87
# count_count : 3회
# time_count : 18:03
# pass_count : 0.08
# pass_count : 58.45
# pass_count : 64.76
# pass_count : 0.146
# pass_count : 70.05
# pass_count : 68.23
# pass_count : 0.164
# pass_count : 67.95
# pass_count : 69.12
# date_count : 2월17일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.165
# pass_count : 65.95
# pass_count : 63.08
# count_count : 2회
# time_count : 9:44
# pass_count : 0.102
# pass_count : 64.25
# pass_count : 57.45
# pass_count : 0.160
# pass_count : 65.94
# pass_count : 67.12
# pass_count : 0.163
# pass_count : 69.02
# pass_count : 67.94
# count_count : 3회
# time_count : 18:40
# pass_count : 0.074
# pass_count : 67.4
# pass_count : 59.15
# date_count : 2월18일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.182
# pass_count : 67.01
# pass_count : 소음계오류
# count_count : 2회
# time_count : 9:38
# pass_count : 0.130
# pass_count : 65.15
# pass_count : 57.74
# pass_count : 0.151
# pass_count : 67.67
# pass_count : 69.59
# pass_count : 0.178
# pass_count : 68.31
# pass_count : 65.22
# count_count : 3회
# time_count : 18:42
# pass_count : 0.071
# pass_count : 68.43
# pass_count : 59.37
# date_count : 2월19일
# count_count : 1회
# time_count : 7:02
# pass_count : 0.128
# pass_count : 64.89
# pass_count : 61.34
# count_count : 2회
# time_count : 9:38
# pass_count : 0.124
# pass_count : 64.76
# pass_count : 68.95
# pass_count : 0.127
# pass_count : 68.26
# pass_count : 67.50
# pass_count : 0.126
# pass_count : 66.60
# pass_count : 61.34
# count_count : 3회
# time_count : 18:42
# pass_count : 0.156
# pass_count : 66.24
# pass_count : 68.65
# date_count : 2월20일
# count_count : 1회
# time_count : 7:01
# pass_count : NT
# pass_count : NT
# pass_count : NT
# count_count : 2회
# time_count : 9:47
# pass_count : 0.072
# pass_count : 59.48
# pass_count : 61.03
# pass_count : 0.113
# pass_count : 68.83
# pass_count : 68.07
# pass_count : 0.151
# pass_count : 68.52
# pass_count : 62.64
# count_count : 3회
# time_count : 18:13
# pass_count : 0.077
# pass_count : 67.20
# pass_count : 62.12
# ['삼부봉제', '우진아트빌3차', '성포중학교', '태영빌', '코리안바베큐', '우창아트빌']

# %%
# 6. ListToDict
result = {}
value = []

date_key, time_key, location_key = None, None, None

for item in section2:
    for x, i in enumerate(item):
        if re.match(r'\d+월\d+일', i):
            date_key = i
        elif re.match(r'\d+회', i):
            count_key = i
        elif re.match(r'\d+:\d+', i):
            time_key = i
        elif i not in location:
            value.append(i)
        elif i in location:
            location_key = i
            result[location_key] = {} if location_key not in result else result[location_key]
            result[location_key][f'{time_key} | {count_key}'] = {'일시' : f'{date_key} {time_key}'}

            for j in range(len(title)):
                try:
                    tmp = float(value[j])
                except ValueError:
                    tmp = np.nan
                finally:
                    result[location_key][f'{time_key} | {count_key}'][title[j]] = tmp
            value = []

print(result)
# Out:
# {'삼부봉제': {'7:01 | 1회': {'일시': '2월20일 7:01', '발파진동(cm/s)': nan, '진동레벨dB(V)': nan, '소음레벨dB(A)': nan}, '14:23 | 3회': {'일시': '2월1일 14:23', '발파진동(cm/s)': 0.007, '진동레벨dB(V)': 44.01, '소음레벨dB(A)': 63.39}, '15:47 | 3회': {'일시': '2월2일 15:47', '발파진동(cm/s)': 0.045, '진동레벨dB(V)': 56.21, '소음레벨dB(A)': 53.98}, '7:00 | 1회': {'일시': '2월3일 7:00', '발파진동(cm/s)': 0.056, '진동레벨dB(V)': 60.14, '소음레벨dB(A)': 54.21}, '16:40 | 3회': {'일시': '2월3일 16:40', '발파진동(cm/s)': 0.085, '진동레벨dB(V)': 64.51, '소음레벨dB(A)': 57.47}, '16:37 | 2회': {'일시': '2월4일 16:37', '발파진동(cm/s)': 0.037, '진동레벨dB(V)': 54.78, '소음레벨dB(A)': 53.2}, '7:03 | 1회': {'일시': '2월15일 7:03', '발파진동(cm/s)': 0.153, '진동레벨dB(V)': 65.84, '소음레벨dB(A)': 60.94}, '17:41 | 3회': {'일시': '2월5일 17:41', '발파진동(cm/s)': 0.039, '진동레벨dB(V)': 54.83, '소음레벨dB(A)': 60.3}, '12:11 | 2회': {'일시': '2월6일 12:11', '발파진동(cm/s)': 0.022, '진동레벨dB(V)': 51.79, '소음레벨dB(A)': 49.5}, '7:02 | 1회': {'일시': '2월19일 7:02', '발파진동(cm/s)': 0.128, '진동레벨dB(V)': 64.89, '소음레벨dB(A)': 61.34}, '17:52 | 3회': {'일시': '2월7일 17:52', '발파진동(cm/s)': 0.04, '진동레벨dB(V)': 60.85, '소음레벨dB(A)': 51.61}, '7:04 | 1회': {'일시': '2월8일 7:04', '발파진동(cm/s)': 0.021, '진동레벨dB(V)': 54.98, '소음레벨dB(A)': 52.62}, '15:06 | 3회': {'일시': '2월8일 15:06', '발파진동(cm/s)': 0.036, '진동레벨dB(V)': 61.81, '소음레벨dB(A)': 54.48}, '9:34 | 2회': {'일시': '2월10일 9:34', '발파진동(cm/s)': 0.058, '진동레벨dB(V)': 63.49, '소음레벨dB(A)': 56.23}, '18:40 | 3회': {'일시': '2월17일 18:40', '발파진동(cm/s)': 0.074, '진동레벨dB(V)': 67.4, '소음레벨dB(A)': 59.15}, '18:42 | 3회': {'일시': '2월19일 18:42', '발파진동(cm/s)': 0.156, '진동레벨dB(V)': 66.24, '소음레벨dB(A)': 68.65}, '10:45 | 2회': {'일시': '2월13일 10:45', '발파진동(cm/s)': 0.094, '진동레벨dB(V)': 67.38, '소음레벨dB(A)': 59.67}, '14:27 | 2회': {'일시': '2월14일 14:27', '발파진동(cm/s)': 0.092, '진동레벨dB(V)': 69.86, '소음레벨dB(A)': 58.72}, '18:29 | 3회': {'일시': '2월15일 18:29', '발파진동(cm/s)': 0.124, '진동레벨dB(V)': 65.04, '소음레벨dB(A)': 60.35}, '12:02 | 2회': {'일시': '2월16일 12:02', '발파진동(cm/s)': 0.194, '진동레벨dB(V)': 66.65, '소음레벨dB(A)': 61.87}, '18:13 | 3회': {'일시': '2월20일 18:13', '발파진동(cm/s)': 0.077, '진동레벨dB(V)': 67.2, '소음레벨dB(A)': 62.12}}, '우진아트빌3차': {'9:00 | 2회': {'일시': '2월1일 9:00', '발파진동(cm/s)': 0.04, '진동레벨dB(V)': 53.6, '소음레벨dB(A)': 55.74}, '8:59 | 2회': {'일시': '2월2일 8:59', '발파진동(cm/s)': 0.049, '진동레벨dB(V)': 54.47, '소음레벨dB(A)': 55.4}, '9:01 | 2회': {'일시': '2월3일 9:01', '발파진동(cm/s)': 0.017, '진동레벨dB(V)': 49.25, '소음레벨dB(A)': 53.64}, '8:30 | 1회': {'일시': '2월4일 8:30', '발파진동(cm/s)': 0.012, '진동레벨dB(V)': 45.74, '소음레벨dB(A)': 43.27}, '11:12 | 2회': {'일시': '2월5일 11:12', '발파진동(cm/s)': 0.023, '진동레벨dB(V)': 48.72, '소음레벨dB(A)': 49.99}}, '코리안바베큐': {'9:00 | 2회': {'일시': '2월1일 9:00', '발파진동(cm/s)': 0.086, '진동레벨dB(V)': 58.9, '소음레벨dB(A)': 66.99}, '18:10 | 4회': {'일시': '2월1일 18:10', '발파진동(cm/s)': 0.158, '진동레벨dB(V)': 61.28, '소음레벨dB(A)': 67.63}, '8:59 | 2회': {'일시': '2월2일 8:59', '발파진동(cm/s)': 0.158, '진동레벨dB(V)': 69.1, '소음레벨dB(A)': 74.56}, '18:09 | 4회': {'일시': '2월2일 18:09', '발파진동(cm/s)': 0.156, '진동레벨dB(V)': 67.18, '소음레벨dB(A)': 68.34}, '9:01 | 2회': {'일시': '2월3일 9:01', '발파진동(cm/s)': 0.141, '진동레벨dB(V)': 66.73, '소음레벨dB(A)': 72.01}, '8:30 | 1회': {'일시': '2월4일 8:30', '발파진동(cm/s)': 0.04, '진동레벨dB(V)': 56.52, '소음레벨dB(A)': 64.48}, '11:12 | 2회': {'일시': '2월5일 11:12', '발파진동(cm/s)': 0.135, '진동레벨dB(V)': 63.59, '소음레벨dB(A)': 70.59}, '7:02 | 1회': {'일시': '2월10일 7:02', '발파진동(cm/s)': 0.115, '진동레벨dB(V)': 64.94, '소음레벨dB(A)': 67.94}, '18:32 | 3회': {'일시': '2월6일 18:32', '발파진동(cm/s)': 0.146, '진동레벨dB(V)': 67.43, '소음레벨dB(A)': 73.11}, '9:04 | 2회': {'일시': '2월9일 9:04', '발파진동(cm/s)': 0.156, '진동레벨dB(V)': 66.8, '소음레벨dB(A)': 71.27}, '8:34 | 2회': {'일시': '2월8일 8:34', '발파진동(cm/s)': 0.213, '진동레벨dB(V)': 70.88, '소음레벨dB(A)': 71.42}, '17:04 | 4회': {'일시': '2월8일 17:04', '발파진동(cm/s)': 0.141, '진동레벨dB(V)': 67.62, '소음레벨dB(A)': 70.69}, '18:01 | 4회': {'일시': '2월9일 18:01', '발파진동(cm/s)': 0.139, '진동레벨dB(V)': 66.19, '소음레벨dB(A)': 67.79}, '17:42 | 3회': {'일시': '2월10일 17:42', '발파진동(cm/s)': 0.137, '진동레벨dB(V)': 66.11, '소음레벨dB(A)': 66.8}, '9:50 | 2회': {'일시': '2월11일 9:50', '발파진동(cm/s)': 0.152, '진동레벨dB(V)': 68.25, '소음레벨dB(A)': 68.25}, '9:52 | 2회': {'일시': '2월12일 9:5 ...

# %%
df_list = []

for i in result:
    df_list.append(pd.DataFrame(result[i]).transpose())

# %%
def classficationEveningData(df):
    new_columns = []

    for x, i in enumerate(list(df.index)):
        time = int(df.loc[i, '일시'].split(" ")[1].split(":")[0])
        if time >= 18:
            new_columns.append(df.loc[i, '소음레벨dB(A)'])
            df.loc[i, '소음레벨dB(A)'] = np.nan
        else:
            new_columns.append(np.nan)

    df['After 18:00'] = new_columns
    df.loc['MIN'] = df.min()
    df.loc['MAX'] = df.max()

    return df

# %%
for i in df_list:
    print(classficationEveningData(i))
# Out:
#                      일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  After 18:00
# 7:01 | 1회    2월20일 7:01        NaN       NaN       NaN          NaN
# 14:23 | 3회   2월1일 14:23      0.007     44.01     63.39          NaN
# 15:47 | 3회   2월2일 15:47      0.045     56.21     53.98          NaN
# 7:00 | 1회     2월3일 7:00      0.056     60.14     54.21          NaN
# 16:40 | 3회   2월3일 16:40      0.085     64.51     57.47          NaN
# 16:37 | 2회   2월4일 16:37      0.037     54.78      53.2          NaN
# 7:03 | 1회    2월15일 7:03      0.153     65.84     60.94          NaN
# 17:41 | 3회   2월5일 17:41      0.039     54.83      60.3          NaN
# 12:11 | 2회   2월6일 12:11      0.022     51.79      49.5          NaN
# 7:02 | 1회    2월19일 7:02      0.128     64.89     61.34          NaN
# 17:52 | 3회   2월7일 17:52       0.04     60.85     51.61          NaN
# 7:04 | 1회     2월8일 7:04      0.021     54.98     52.62          NaN
# 15:06 | 3회   2월8일 15:06      0.036     61.81     54.48          NaN
# 9:34 | 2회    2월10일 9:34      0.058     63.49     56.23          NaN
# 18:40 | 3회  2월17일 18:40      0.074      67.4       NaN        59.15
# 18:42 | 3회  2월19일 18:42      0.156     66.24       NaN        68.65
# 10:45 | 2회  2월13일 10:45      0.094     67.38     59.67          NaN
# 14:27 | 2회  2월14일 14:27      0.092     69.86     58.72          NaN
# 18:29 | 3회  2월15일 18:29      0.124     65.04       NaN        60.35
# 12:02 | 2회  2월16일 12:02      0.194     66.65     61.87          NaN
# 18:13 | 3회  2월20일 18:13      0.077      67.2       NaN        62.12
# MIN          2월10일 9:34      0.007     44.01      49.5        59.15
# MAX           2월8일 7:04      0.194     69.86     63.39        68.65
#                     일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  After 18:00
# 9:00 | 2회    2월1일 9:00       0.04      53.6     55.74          NaN
# 8:59 | 2회    2월2일 8:59      0.049     54.47      55.4          NaN
# 9:01 | 2회    2월3일 9:01      0.017     49.25     53.64          NaN
# 8:30 | 1회    2월4일 8:30      0.012     45.74     43.27          NaN
# 11:12 | 2회  2월5일 11:12      0.023     48.72     49.99          NaN
# MIN          2월1일 9:00      0.012     45.74     43.27          NaN
# MAX         2월5일 11:12      0.049     54.47     55.74          NaN
#                      일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  After 18:00
# 9:00 | 2회     2월1일 9:00      0.086      58.9     66.99          NaN
# 18:10 | 4회   2월1일 18:10      0.158     61.28       NaN        67.63
# 8:59 | 2회     2월2일 8:59      0.158      69.1     74.56          NaN
# 18:09 | 4회   2월2일 18:09      0.156     67.18       NaN        68.34
# 9:01 | 2회     2월3일 9:01      0.141     66.73     72.01          NaN
# 8:30 | 1회     2월4일 8:30       0.04     56.52     64.48          NaN
# 11:12 | 2회   2월5일 11:12      0.135     63.59     70.59          NaN
# 7:02 | 1회    2월10일 7:02      0.115     64.94     67.94          NaN
# 18:32 | 3회   2월6일 18:32      0.146     67.43       NaN        73.11
# 9:04 | 2회     2월9일 9:04      0.156      66.8     71.27          NaN
# 8:34 | 2회     2월8일 8:34      0.213     70.88     71.42          NaN
# 17:04 | 4회   2월8일 17:04      0.141     67.62     70.69          NaN
# 18:01 | 4회   2월9일 18:01      0.139     66.19       NaN        67.79
# 17:42 | 3회  2월10일 17:42      0.137     66.11      66.8          NaN
# 9:50 | 2회    2월11일 9:50      0.152     68.25     68.25          NaN
# 9:52 | 2회    2월12일 9:52      0.167     70.68     71.18          NaN
# 7:04 | 1회    2월13일 7:04      0.207      73.2     73.37          NaN
# 17:12 | 3회  2월13일 17:12      0.104     65.94     67.33          NaN
# 8:32 | 1회    2월16일 8:32      0.118     66.01     67.26          NaN
# 18:18 | 3회  2월14일 18:18      0.105      67.1       NaN        67.57
# 10:14 | 2회  2월15일 10:14      0.149     68.15     69.49          NaN
# 18:03 | 3회  2월16일 18:03      0.146     70.05       NaN        68.23
# 9:44 | 2회    2월17일 9:44       0.16     65.94     67.12          NaN
# 9:38 | 2회    2월19일 9:38      0.127     68.26      67.5          NaN
# 9:47 | 2회    2월20일 9:47      0.113     68.83     68.07          NaN
# MIN         2월10일 17:42       0.04     56.52     64.48        67.57
# MAX           2월9일 9:04      0.213      73.2     74.56        73.11
#                      일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  After 18:00
# 9:00 | 2회     2월1일 9:00      0.051     58.37     63.65          NaN
# 18:10 | 4회   2월1일 18:10      0.114     63.27       NaN        71.88
# 8:59 | 2회     2월2일 8:59      0.059      59.5     61.23          NaN
# 18:09 | 4회   2월2일 18:09      0.066      62.0       NaN        69.50
# 9:01 | 2회     2월3일 9:01       0.06     60.59     72.76          NaN
# 8:30 | 1회     2월4일 8:30        NaN       NaN       NaN          NaN
# 11:12 | 2회   2월5일 11:12      0.063     56.91      63.3          NaN
# 7:02 | 1회    2월10일 7:02       0.17      66.9     62.26          NaN
# 18:32 | 3회   2월6일 18:32      0.082      64.7       NaN        63.95
# 9:04 | 2회     2월9일 9:04        NaN       NaN       NaN          NaN
# 8:34 | 2회     2월8일 8:34      0.102     62.74     62.17          NaN
# 17:04 | 4회   2월8일 17:04      0.106     65.99     60.05          NaN
# 18:01 | 4회   2월9일 18:01      0.144     64.79       NaN        66.82
# 17:42 | 3회  2월10일 17:42      0.139     64.91     62.36          NaN
# 9:50 | 2회    2월11일 9:50      0.102     65.63      70.1          NaN
# 9:52 | 2회    2월12일 9:52      0.152     69.56     63.58          NaN
# 7:04 | 1회    2월13일 7:04      0.206     71.96     65.78          NaN
# 17:12 | 3회  2월13일 17:12      0.123     67.55     61.29          NaN
# 8:32 | 1회    2월16일 8:32      0.146     66.68      60.5          NaN
# 18:18 | 3회  2월14일 18:18      0.111     65.72       NaN        58.58
# 10:14 | 2회  2월15일 10:14      0.135     68.46     74.55          NaN
# 18:03 | 3회  2월16일 18:03      0.164     67.95       NaN        69.12
# 9:44 | 2회    2월17일 9:44      0.163     69.02     67.94          NaN
# 9:38 | 2회    2월19일 9:38      0.126      66.6     61.34          NaN
# 9:47 | 2회    2월20일 9:47      0.151     68.52     62.64          NaN
# MIN         2월10일 17:42      0.051     56.91     60.05        58.58
# MAX           2월9일 9:04      0.206     71.96     74.55        71.88
#                      일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  After 18:00
# 18:10 | 4회   2월1일 18:10      0.071     57.84       NaN        58.95
# 18:09 | 4회   2월2일 18:09      0.045     52.93       NaN        70.09
# 7:02 | 1회    2월10일 7:02      0.034     52.37     55.14          NaN
# 18:32 | 3회   2월6일 18:32      0.082     61.22       NaN        56.69
# 9:04 | 2회     2월9일 9:04      0.037     52.35     56.71          NaN
# 8:34 | 2회     2월8일 8:34       0.06     54.02     56.92          NaN
# 17:04 | 4회   2월8일 17:04      0.047     54.49     61.56          NaN
# 18:01 | 3회   2월9일 18:01      0.093     58.63       NaN        57.86
# 18:01 | 4회   2월9일 18:01      0.006     44.67       NaN        50.33
# 17:42 | 3회  2월10일 17:42      0.032     52.28     57.97          NaN
# MIN         2월10일 17:42      0.006     44.67     55.14        50.33
# MAX           2월9일 9:04      0.093     61.22     61.56        70.09
#                      일시 발파진동(cm/s) 진동레벨dB(V) 소음레벨dB(A)  After 18:00
# 9:50 | 2회    2월11일 9:50      0.092     61.78     60.18          NaN
# 9:52 | 2회    2월12일 9:52       0.04      58.1     59.67          NaN
# 7:04 | 1회    2월13일 7:04        NaN       NaN       NaN          NaN
# 17:12 | 3회  2월13일 17:12      0.027     53.66     57.05          NaN
# 8:32 | 1회    2월16일 8:32      0.169     64.83     67.94          NaN
# 18:18 | 3회  2월14일 18:18      0.088     61.98       NaN        60.68
# 10:14 | 2회  2월15일 10:14      0.062     57.64     60.18          NaN
# 18:03 | 3회  2월16일 18:03       0.08     58.45       NaN        64.76
# 9:44 | 2회    2월17일 9:44      0.102     64.25     57.45          NaN
# 9:38 | 2회    2월19일 9:38      0.124     64.76     68.95          NaN
# 9:47 | 2회    2월20일 9:47      0.072     59.48     61.03          NaN
# MIN          2월11일 9:50      0.027     53.66     57.05        60.68
# MAX          2월20일 9:47      0.169     64.83     68.95        64.76
